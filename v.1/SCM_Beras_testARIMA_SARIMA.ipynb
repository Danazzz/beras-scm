# %% [markdown]
# <a href="https://colab.research.google.com/github/Danazzz/dataset-beras-scm/blob/main/SCM_Beras1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import zipfile, os
import numpy as np
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
from statsmodels.tsa.stattools import adfuller
plt.rcParams['figure.figsize'] = 15, 6            #agar semua plot ukurannya sama
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Specify the path to your CSV file
file_path1 = '/Users/danawardhiana/Projects/dataset-beras/export-produsen-2-2.csv'
file_path2 = '/Users/danawardhiana/Projects/dataset-beras/Tabel Harga Berdasarkan Daerah Jabar.csv'

# Use pandas to read the CSV file
df1 = pd.read_csv(file_path1)
df2 = pd.read_csv(file_path2)

# Now 'data' is a pandas DataFrame containing the data from the CSV file

# %%
#Load data BI
converters = {
    'Beras': lambda x: str(x.replace(',', '')),
    'Beras Kualitas Bawah I' : lambda x: str(x.replace(',', '')),
    'Beras Kualitas Medium I' : lambda x: str(x.replace(',', '')),
    'Beras Kualitas Super I' : lambda x: str(x.replace(',', '')),
}

df1 = pd.read_csv('Tabel Harga Berdasarkan Daerah Jabar.csv', converters=converters)
df1
# Out:
#          Komoditas  Beras Beras Kualitas Bawah I Beras Kualitas Bawah II  \
# 0     01/ 01/ 2020      -                      -                       -
# 1     02/ 01/ 2020  11150                  10100                   9,500
# 2     03/ 01/ 2020  11150                  10100                   9,500
# 3     06/ 01/ 2020  11150                  10150                   9,550
# 4     07/ 01/ 2020  11200                  10200                   9,650
# ...            ...    ...                    ...                     ...
# 1093  11/ 03/ 2024  15800                  14950                  14,500
# 1094  12/ 03/ 2024  15800                  14950                  14,500
# 1095  13/ 03/ 2024  15750                  14900                  14,400
# 1096  14/ 03/ 2024  15750                  14900                  14,400
# 1097  15/ 03/ 2024  15750                  14950                  14,400
#
#      Beras Kualitas Medium I Beras Kualitas Medium II Beras Kualitas Super I  \
# 0                          -                        -                      -
# 1                      11350                   10,850                  12900
# 2                      11350                   10,850                  12900
# 3                      11350                   10,850                  12900
# 4                      11400                   10,900                  12950
# ...                      ...                      ...                    ...
# 1093                   16050                   15,550                  17250
# 1094                   16050                   15,550                  17250
# 1095                   16000                   15,450                  17200
# 1096                   16000                   15,450                  17200
# 1097                   16000                   15,500                  17200
#
#      Beras Kualitas Super II
# 0                          -
# 1                     12,100
# 2                     12,100
# 3                     12,100
# 4                     12,150
# ...                      ...
# 1093                  16,550
# 1094                  16,550
# 1095                  16,550
# 1096                  16,550
# 1097                  16,550
#
# [1098 rows x 8 columns]

# %%
print('Data Types:')
print(df1.dtypes)
# Out:
# Data Types:
# Komoditas                   object
# Beras                       object
# Beras Kualitas Bawah I      object
# Beras Kualitas Bawah II     object
# Beras Kualitas Medium I     object
# Beras Kualitas Medium II    object
# Beras Kualitas Super I      object
# Beras Kualitas Super II     object
# dtype: object

# %%
#Mengubah tanggal menjadi index
con=df1['Komoditas']
df1['Komoditas'] = pd.to_datetime(df1['Komoditas'], format='%d/ %m/ %Y')
df1.set_index('Komoditas', inplace=True)
#check datatype of index
df1.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14',
#                ...
#                '2024-03-04', '2024-03-05', '2024-03-06', '2024-03-07',
#                '2024-03-08', '2024-03-11', '2024-03-12', '2024-03-13',
#                '2024-03-14', '2024-03-15'],
#               dtype='datetime64[ns]', name='Komoditas', length=1098, freq=None)

# %%
df1 = df1.iloc[:, [0, 1, 3, 5]]
df1
# Out:
#             Beras Beras Kualitas Bawah I Beras Kualitas Medium I  \
# Komoditas
# 2020-01-01      -                      -                       -
# 2020-01-02  11150                  10100                   11350
# 2020-01-03  11150                  10100                   11350
# 2020-01-06  11150                  10150                   11350
# 2020-01-07  11200                  10200                   11400
# ...           ...                    ...                     ...
# 2024-03-11  15800                  14950                   16050
# 2024-03-12  15800                  14950                   16050
# 2024-03-13  15750                  14900                   16000
# 2024-03-14  15750                  14900                   16000
# 2024-03-15  15750                  14950                   16000
#
#            Beras Kualitas Super I
# Komoditas
# 2020-01-01                      -
# 2020-01-02                  12900
# 2020-01-03                  12900
# 2020-01-06                  12900
# 2020-01-07                  12950
# ...                           ...
# 2024-03-11                  17250
# 2024-03-12                  17250
# 2024-03-13                  17200
# 2024-03-14                  17200
# 2024-03-15                  17200
#
# [1098 rows x 4 columns]

# %%
# Mengubah - menjadi 0
df1.replace('-', np.nan, inplace=True)
df1
# Out:
# /var/folders/3s/37cdhq1x7fdcds5p4y_vnbp00000gn/T/ipykernel_93536/3795684999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('-', np.nan, inplace=True)
#             Beras Beras Kualitas Bawah I Beras Kualitas Medium I  \
# Komoditas
# 2020-01-01    NaN                    NaN                     NaN
# 2020-01-02  11150                  10100                   11350
# 2020-01-03  11150                  10100                   11350
# 2020-01-06  11150                  10150                   11350
# 2020-01-07  11200                  10200                   11400
# ...           ...                    ...                     ...
# 2024-03-11  15800                  14950                   16050
# 2024-03-12  15800                  14950                   16050
# 2024-03-13  15750                  14900                   16000
# 2024-03-14  15750                  14900                   16000
# 2024-03-15  15750                  14950                   16000
#
#            Beras Kualitas Super I
# Komoditas
# 2020-01-01                    NaN
# 2020-01-02                  12900
# 2020-01-03                  12900
# 2020-01-06                  12900
# 2020-01-07                  12950
# ...                           ...
# 2024-03-11                  17250
# 2024-03-12                  17250
# 2024-03-13                  17200
# 2024-03-14                  17200
# 2024-03-15                  17200
#
# [1098 rows x 4 columns]

# %%
df1 = df1.astype('Int64')
df1
# Out:
#             Beras  Beras Kualitas Bawah I  Beras Kualitas Medium I  \
# Komoditas
# 2020-01-01   <NA>                    <NA>                     <NA>
# 2020-01-02  11150                   10100                    11350
# 2020-01-03  11150                   10100                    11350
# 2020-01-06  11150                   10150                    11350
# 2020-01-07  11200                   10200                    11400
# ...           ...                     ...                      ...
# 2024-03-11  15800                   14950                    16050
# 2024-03-12  15800                   14950                    16050
# 2024-03-13  15750                   14900                    16000
# 2024-03-14  15750                   14900                    16000
# 2024-03-15  15750                   14950                    16000
#
#             Beras Kualitas Super I
# Komoditas
# 2020-01-01                    <NA>
# 2020-01-02                   12900
# 2020-01-03                   12900
# 2020-01-06                   12900
# 2020-01-07                   12950
# ...                            ...
# 2024-03-11                   17250
# 2024-03-12                   17250
# 2024-03-13                   17200
# 2024-03-14                   17200
# 2024-03-15                   17200
#
# [1098 rows x 4 columns]

# %%
df1.info()
df1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1098 entries, 2020-01-01 to 2024-03-15
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Beras                    1050 non-null   Int64
#  1   Beras Kualitas Bawah I   1050 non-null   Int64
#  2   Beras Kualitas Medium I  1050 non-null   Int64
#  3   Beras Kualitas Super I   1050 non-null   Int64
# dtypes: Int64(4)
# memory usage: 47.2 KB
# (1098, 4)

# %%
converters = {
    'Luas Panen Padi': lambda x: str(x.replace('.', '')),
    'GKP Tingkat Petani': lambda x: str(x.replace('.', '')),
    'GKP Tingkat Penggilingan' : lambda x: str(x.replace('.', '')),
    'GKG Tingkat Penggilingan' : lambda x: str(x.replace('.', '')),
    'Beras Medium Penggilingan' : lambda x: str(x.replace('.', '')),
    'Beras Premium Penggilingan' : lambda x: str(x.replace('.', '')),
}

#Load data
df2 = pd.read_csv('export-produsen-2-2.csv', converters=converters)
# print(df2.head())
df2
# Out:
#        Komoditas Luas Panen Padi GKP Tingkat Petani GKP Tingkat Penggilingan  \
# 0     01/01/2020              20               3700                     4000
# 1     02/01/2020               -                  -                        -
# 2     03/01/2020               -                  -                        -
# 3     04/01/2020               -                  -                        -
# 4     05/01/2020               -                  -                        -
# ...          ...             ...                ...                      ...
# 1531  11/03/2024              10               6760                     7140
# 1532  12/03/2024              10               6530                     6930
# 1533  13/03/2024              10               6480                     6920
# 1534  14/03/2024              10               6510                     7060
# 1535  15/03/2024              10               6480                     6930
#
#      GKG Tingkat Penggilingan Beras Medium Penggilingan  \
# 0                        4500                      8200
# 1                           -                         -
# 2                           -                         -
# 3                           -                         -
# 4                           -                         -
# ...                       ...                       ...
# 1531                     8330                     14180
# 1532                     8260                     14140
# 1533                     8240                     14040
# 1534                     8240                     14050
# 1535                     8190                     14120
#
#      Beras Premium Penggilingan Jagung Pipilan Kering  \
# 0                          9200                     -
# 1                             -                     -
# 2                             -                     -
# 3                             -                     -
# 4                             -                     -
# ...                         ...                   ...
# 1531                      15640                 5.540
# 1532                      15480                 5.250
# 1533                      15460                 5.280
# 1534                      15510                 5.280
# 1535                      15470                 5.460
#
#      Kedelai Biji Kering (Lokal) Bawang Merah Cabai Merah Keriting  \
# 0                              -            -                    -
# 1                              -            -                    -
# 2                              -            -                    -
# 3                              -            -                    -
# 4                              -            -                    -
# ...                          ...          ...                  ...
# 1531                      10.610       15.990               41.880
# 1532                      10.610       16.330               42.830
# 1533                      10.310       15.990               43.770
# 1534                      10.310       15.840               45.070
# 1535                      10.310       15.370               44.550
#
#      Cabai Rawit Merah Sapi (Hidup) Ayam Ras Pedaging (Hidup) Telur Ayam Ras  \
# 0                    -            -                         -              -
# 1                    -            -                         -              -
# 2                    -            -                         -              -
# 3                    -            -                         -              -
# 4                    -            -                         -              -
# ...                ...          ...                       ...            ...
# 1531            45.050       54.440                    24.480         27.540
# 1532            43.390       54.470                    24.480         28.260
# 1533            42.270       54.560                    24.000         28.200
# 1534            41.840       54.550                    24.010         28.130
# 1535            42.570       54.480                    23.810         28.100
#
#      Stok GKG Tingkat Penggilingan Stok Beras Tingkat Penggilingan
# 0                              600                             150
# 1                                -                               -
# 2                                -                               -
# 3                                -                               -
# 4                                -                               -
# ...                            ...                             ...
# 1531                           120                              80
# 1532                           120                              80
# 1533                           100                              60
# 1534                           150                              70
# 1535                           150                              80
#
# [1536 rows x 17 columns]

# %% [markdown]
# PRODUSEN
# Panel Harga Pangan pada tingkat produsen yang diamati meliputi:
# - Luas Lahan/Sawah Padi, persentase (%) luas panen Padi di kecamatan sentra produksi.
# - GKP Tingkat Petani, harga di Petani (Rp/Kg)
# - GKP Tingkat Penggilingan, harga di Penggilingan (Rp/Kg)
# - GKG Tingkat Penggilingan, harga di Penggilingan (Rp/Kg)
# - Beras Medium Tingkat Penggilingan, harga di Penggilingan (Rp/Kg)
# - Beras Premium Tingkat Penggilingan, harga di Penggilingan (Rp/Kg)
# - Stok GKG Tingkat Penggilingan, stok dalam satuan Kwintal
# - Stok Beras Tingkat Penggilingan, stok dalam satuan Kwintal

# %%
print('Data Types:')
print(df2.dtypes)
# Out:
# Data Types:
# Komoditas                          object
# Luas Panen Padi                    object
# GKP Tingkat Petani                 object
# GKP Tingkat Penggilingan           object
# GKG Tingkat Penggilingan           object
# Beras Medium Penggilingan          object
# Beras Premium Penggilingan         object
# Jagung Pipilan Kering              object
# Kedelai Biji Kering (Lokal)        object
# Bawang Merah                       object
# Cabai Merah Keriting               object
# Cabai Rawit Merah                  object
# Sapi (Hidup)                       object
# Ayam Ras Pedaging (Hidup)          object
# Telur Ayam Ras                     object
# Stok GKG Tingkat Penggilingan      object
# Stok Beras Tingkat Penggilingan    object
# dtype: object

# %%
#Mengubah tanggal menjadi index
con=df2['Komoditas']
df2['Komoditas'] = pd.to_datetime(df2['Komoditas'], format='%d/%m/%Y')
df2.set_index('Komoditas', inplace=True)
#check datatype of index
df2.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-09',
#                '2024-03-10', '2024-03-11', '2024-03-12', '2024-03-13',
#                '2024-03-14', '2024-03-15'],
#               dtype='datetime64[ns]', name='Komoditas', length=1536, freq=None)

# %%
df2 = df2.iloc[:, [0, 1, 2, 3, 4, 5, 14, 15]]
df2
# Out:
#            Luas Panen Padi GKP Tingkat Petani GKP Tingkat Penggilingan  \
# Komoditas
# 2020-01-01              20               3700                     4000
# 2020-01-02               -                  -                        -
# 2020-01-03               -                  -                        -
# 2020-01-04               -                  -                        -
# 2020-01-05               -                  -                        -
# ...                    ...                ...                      ...
# 2024-03-11              10               6760                     7140
# 2024-03-12              10               6530                     6930
# 2024-03-13              10               6480                     6920
# 2024-03-14              10               6510                     7060
# 2024-03-15              10               6480                     6930
#
#            GKG Tingkat Penggilingan Beras Medium Penggilingan  \
# Komoditas
# 2020-01-01                     4500                      8200
# 2020-01-02                        -                         -
# 2020-01-03                        -                         -
# 2020-01-04                        -                         -
# 2020-01-05                        -                         -
# ...                             ...                       ...
# 2024-03-11                     8330                     14180
# 2024-03-12                     8260                     14140
# 2024-03-13                     8240                     14040
# 2024-03-14                     8240                     14050
# 2024-03-15                     8190                     14120
#
#            Beras Premium Penggilingan Stok GKG Tingkat Penggilingan  \
# Komoditas
# 2020-01-01                       9200                           600
# 2020-01-02                          -                             -
# 2020-01-03                          -                             -
# 2020-01-04                          -                             -
# 2020-01-05                          -                             -
# ...                               ...                           ...
# 2024-03-11                      15640                           120
# 2024-03-12                      15480                           120
# 2024-03-13                      15460                           100
# 2024-03-14                      15510                           150
# 2024-03-15                      15470                           150
#
#            Stok Beras Tingkat Penggilingan
# Komoditas
# 2020-01-01                             150
# 2020-01-02                               -
# 2020-01-03                               -
# 2020-01-04                               -
# 2020-01-05                               -
# ...                                    ...
# 2024-03-11                              80
# 2024-03-12                              80
# 2024-03-13                              60
# 2024-03-14                              70
# 2024-03-15                              80
#
# [1536 rows x 8 columns]

# %%
# Mengubah - menjadi 0
df2.replace('-', np.nan, inplace=True)
df2
# Out:
# /var/folders/3s/37cdhq1x7fdcds5p4y_vnbp00000gn/T/ipykernel_93536/1373517859.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace('-', np.nan, inplace=True)
#            Luas Panen Padi GKP Tingkat Petani GKP Tingkat Penggilingan  \
# Komoditas
# 2020-01-01              20               3700                     4000
# 2020-01-02             NaN                NaN                      NaN
# 2020-01-03             NaN                NaN                      NaN
# 2020-01-04             NaN                NaN                      NaN
# 2020-01-05             NaN                NaN                      NaN
# ...                    ...                ...                      ...
# 2024-03-11              10               6760                     7140
# 2024-03-12              10               6530                     6930
# 2024-03-13              10               6480                     6920
# 2024-03-14              10               6510                     7060
# 2024-03-15              10               6480                     6930
#
#            GKG Tingkat Penggilingan Beras Medium Penggilingan  \
# Komoditas
# 2020-01-01                     4500                      8200
# 2020-01-02                      NaN                       NaN
# 2020-01-03                      NaN                       NaN
# 2020-01-04                      NaN                       NaN
# 2020-01-05                      NaN                       NaN
# ...                             ...                       ...
# 2024-03-11                     8330                     14180
# 2024-03-12                     8260                     14140
# 2024-03-13                     8240                     14040
# 2024-03-14                     8240                     14050
# 2024-03-15                     8190                     14120
#
#            Beras Premium Penggilingan Stok GKG Tingkat Penggilingan  \
# Komoditas
# 2020-01-01                       9200                           600
# 2020-01-02                        NaN                           NaN
# 2020-01-03                        NaN                           NaN
# 2020-01-04                        NaN                           NaN
# 2020-01-05                        NaN                           NaN
# ...                               ...                           ...
# 2024-03-11                      15640                           120
# 2024-03-12                      15480                           120
# 2024-03-13                      15460                           100
# 2024-03-14                      15510                           150
# 2024-03-15                      15470                           150
#
#            Stok Beras Tingkat Penggilingan
# Komoditas
# 2020-01-01                             150
# 2020-01-02                             NaN
# 2020-01-03                             NaN
# 2020-01-04                             NaN
# 2020-01-05                             NaN
# ...                                    ...
# 2024-03-11                              80
# 2024-03-12                              80
# 2024-03-13                              60
# 2024-03-14                              70
# 2024-03-15                              80
#
# [1536 rows x 8 columns]

# %%
# ini datanya ada yang gajelas 1
# luas panen 20710?
result = df2[df2['Luas Panen Padi'] == '20710']
print(result)
# Out:
#            Luas Panen Padi GKP Tingkat Petani GKP Tingkat Penggilingan  \
# Komoditas
# 2021-03-12           20710              20710                    20710
#
#            GKG Tingkat Penggilingan Beras Medium Penggilingan  \
# Komoditas
# 2021-03-12                    20710                     20710
#
#            Beras Premium Penggilingan Stok GKG Tingkat Penggilingan  \
# Komoditas
# 2021-03-12                      20710                           NaN
#
#            Stok Beras Tingkat Penggilingan
# Komoditas
# 2021-03-12                             NaN

# %%
df2 = df2.astype('Int64')
df2
# Out:
#             Luas Panen Padi  GKP Tingkat Petani  GKP Tingkat Penggilingan  \
# Komoditas
# 2020-01-01               20                3700                      4000
# 2020-01-02             <NA>                <NA>                      <NA>
# 2020-01-03             <NA>                <NA>                      <NA>
# 2020-01-04             <NA>                <NA>                      <NA>
# 2020-01-05             <NA>                <NA>                      <NA>
# ...                     ...                 ...                       ...
# 2024-03-11               10                6760                      7140
# 2024-03-12               10                6530                      6930
# 2024-03-13               10                6480                      6920
# 2024-03-14               10                6510                      7060
# 2024-03-15               10                6480                      6930
#
#             GKG Tingkat Penggilingan  Beras Medium Penggilingan  \
# Komoditas
# 2020-01-01                      4500                       8200
# 2020-01-02                      <NA>                       <NA>
# 2020-01-03                      <NA>                       <NA>
# 2020-01-04                      <NA>                       <NA>
# 2020-01-05                      <NA>                       <NA>
# ...                              ...                        ...
# 2024-03-11                      8330                      14180
# 2024-03-12                      8260                      14140
# 2024-03-13                      8240                      14040
# 2024-03-14                      8240                      14050
# 2024-03-15                      8190                      14120
#
#             Beras Premium Penggilingan  Stok GKG Tingkat Penggilingan  \
# Komoditas
# 2020-01-01                        9200                            600
# 2020-01-02                        <NA>                           <NA>
# 2020-01-03                        <NA>                           <NA>
# 2020-01-04                        <NA>                           <NA>
# 2020-01-05                        <NA>                           <NA>
# ...                                ...                            ...
# 2024-03-11                       15640                            120
# 2024-03-12                       15480                            120
# 2024-03-13                       15460                            100
# 2024-03-14                       15510                            150
# 2024-03-15                       15470                            150
#
#             Stok Beras Tingkat Penggilingan
# Komoditas
# 2020-01-01                              150
# 2020-01-02                             <NA>
# 2020-01-03                             <NA>
# 2020-01-04                             <NA>
# 2020-01-05                             <NA>
# ...                                     ...
# 2024-03-11                               80
# 2024-03-12                               80
# 2024-03-13                               60
# 2024-03-14                               70
# 2024-03-15                               80
#
# [1536 rows x 8 columns]

# %%
df2.info()
df2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1536 entries, 2020-01-01 to 2024-03-15
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Luas Panen Padi                  1073 non-null   Int64
#  1   GKP Tingkat Petani               1074 non-null   Int64
#  2   GKP Tingkat Penggilingan         1074 non-null   Int64
#  3   GKG Tingkat Penggilingan         1076 non-null   Int64
#  4   Beras Medium Penggilingan        1076 non-null   Int64
#  5   Beras Premium Penggilingan       1076 non-null   Int64
#  6   Stok GKG Tingkat Penggilingan    1063 non-null   Int64
#  7   Stok Beras Tingkat Penggilingan  1063 non-null   Int64
# dtypes: Int64(8)
# memory usage: 120.0 KB
# (1536, 8)

# %%
df3 = pd.merge(df2, df1, on='Komoditas', how='left')
df3
# Out:
#             Luas Panen Padi  GKP Tingkat Petani  GKP Tingkat Penggilingan  \
# Komoditas
# 2020-01-01               20                3700                      4000
# 2020-01-02             <NA>                <NA>                      <NA>
# 2020-01-03             <NA>                <NA>                      <NA>
# 2020-01-04             <NA>                <NA>                      <NA>
# 2020-01-05             <NA>                <NA>                      <NA>
# ...                     ...                 ...                       ...
# 2024-03-11               10                6760                      7140
# 2024-03-12               10                6530                      6930
# 2024-03-13               10                6480                      6920
# 2024-03-14               10                6510                      7060
# 2024-03-15               10                6480                      6930
#
#             GKG Tingkat Penggilingan  Beras Medium Penggilingan  \
# Komoditas
# 2020-01-01                      4500                       8200
# 2020-01-02                      <NA>                       <NA>
# 2020-01-03                      <NA>                       <NA>
# 2020-01-04                      <NA>                       <NA>
# 2020-01-05                      <NA>                       <NA>
# ...                              ...                        ...
# 2024-03-11                      8330                      14180
# 2024-03-12                      8260                      14140
# 2024-03-13                      8240                      14040
# 2024-03-14                      8240                      14050
# 2024-03-15                      8190                      14120
#
#             Beras Premium Penggilingan  Stok GKG Tingkat Penggilingan  \
# Komoditas
# 2020-01-01                        9200                            600
# 2020-01-02                        <NA>                           <NA>
# 2020-01-03                        <NA>                           <NA>
# 2020-01-04                        <NA>                           <NA>
# 2020-01-05                        <NA>                           <NA>
# ...                                ...                            ...
# 2024-03-11                       15640                            120
# 2024-03-12                       15480                            120
# 2024-03-13                       15460                            100
# 2024-03-14                       15510                            150
# 2024-03-15                       15470                            150
#
#             Stok Beras Tingkat Penggilingan  Beras  Beras Kualitas Bawah I  \
# Komoditas
# 2020-01-01                              150   <NA>                    <NA>
# 2020-01-02                             <NA>  11150                   10100
# 2020-01-03                             <NA>  11150                   10100
# 2020-01-04                             <NA>   <NA>                    <NA>
# 2020-01-05                             <NA>   <NA>                    <NA>
# ...                                     ...    ...                     ...
# 2024-03-11                               80  15800                   14950
# 2024-03-12                               80  15800                   14950
# 2024-03-13                               60  15750                   14900
# 2024-03-14                               70  15750                   14900
# 2024-03-15                               80  15750                   14950
#
#             Beras Kualitas Medium I  Beras Kualitas Super I
# Komoditas
# 2020-01-01                     <NA>                    <NA>
# 2020-01-02                    11350                   12900
# 2020-01-03                    11350                   12900
# 2020-01-04                     <NA>                    <NA>
# 2020-01-05                     <NA>                    <NA>
# ...                             ...                     ...
# 2024-03-11                    16050                   17250
# 2024-03-12                    16050                   17250
# 2024-03-13                    16000                   17200
# 2024-03-14                    16000                   17200
# 2024-03-15                    16000                   17200
#
# [1536 rows x 12 columns]

# %%
df3.info()
df3.nunique()

# Menampilkan nilai unik dalam setiap kolom
for col in df3.columns:
    unique_values = df3[col].unique()
    print(f"Nilai unik dalam kolom {col}: {unique_values}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1536 entries, 2020-01-01 to 2024-03-15
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Luas Panen Padi                  1073 non-null   Int64
#  1   GKP Tingkat Petani               1074 non-null   Int64
#  2   GKP Tingkat Penggilingan         1074 non-null   Int64
#  3   GKG Tingkat Penggilingan         1076 non-null   Int64
#  4   Beras Medium Penggilingan        1076 non-null   Int64
#  5   Beras Premium Penggilingan       1076 non-null   Int64
#  6   Stok GKG Tingkat Penggilingan    1063 non-null   Int64
#  7   Stok Beras Tingkat Penggilingan  1063 non-null   Int64
#  8   Beras                            1050 non-null   Int64
#  9   Beras Kualitas Bawah I           1050 non-null   Int64
#  10  Beras Kualitas Medium I          1050 non-null   Int64
#  11  Beras Kualitas Super I           1050 non-null   Int64
# dtypes: Int64(12)
# memory usage: 174.0 KB
# Nilai unik dalam kolom Luas Panen Padi: <IntegerArray>
# [20, <NA>, 0, 10, 20710, 40, 50, 70, 60, 80, 90, 30, 100]
# Length: 13, dtype: Int64
# Nilai unik dalam kolom GKP Tingkat Petani: <IntegerArray>
# [ 3700,  <NA>,  4500,  4400,  4240, 20710,  4150,  4000,  3850,  4160,
#  ...
#   7320,  7140,  7310,  7130,  7200,  7150,  7290,  7030,  6930,  6480]
# Length: 234, dtype: Int64
# Nilai unik dalam kolom GKP Tingkat Penggilingan: <IntegerArray>
# [ 4000,  <NA>,  4700,  4800,  4650, 20710,  4450,  4500,  4150,  4100,
#  ...
#   7600,  7640,  7590,  7610,  7700,  7530,  7510,  7560,  7430,  7140]
# Length: 263, dtype: Int64
# Nilai unik dalam kolom GKG Tingkat Penggilingan: <IntegerArray>
# [ 4500,  <NA>,  5800,  5200,  5600,  5240,  5110,  5230,  5250, 20710,
#  ...
#   9020,  9010,  8980,  8960,  8820,  8500,  8490,  8540,  8550,  8260]
# Length: 294, dtype: Int64
# Nilai unik dalam kolom Beras Medium Penggilingan: <IntegerArray>
# [ 8200,  <NA>,  8800,  8900,  8930, 20710,  8870,  8740,  8790,  8830,
#  ...
#  14460, 14260, 14330, 14240, 14270, 14180, 14140, 14040, 14050, 14120]
# Length: 290, dtype: Int64
# Nilai unik dalam kolom Beras Premium Penggilingan: <IntegerArray>
# [ 9200,  <NA>,  9600,  9990, 10040, 10190, 20710, 10130, 10160, 10030,
#  ...
#  15920, 16080, 16020, 15840, 15660, 15640, 15480, 15460, 15510, 15470]
# Length: 267, dtype: Int64
# Nilai unik dalam kolom Stok GKG Tingkat Penggilingan: <IntegerArray>
# [ 600, <NA>,   20,   70,   30,   40,   60,   90,   50,   80,  150,  100,  110,
#   120,  130,  180,  170,  160,  140,  210,  240,  200,  420,  520,  480,  220,
#   290,  280,  400,  350,  320,  250,  300,  270,  260,  310,  340,  360,  230,
#   500,  190]
# Length: 41, dtype: Int64
# Nilai unik dalam kolom Stok Beras Tingkat Penggilingan: <IntegerArray>
# [ 150, <NA>,   10,   20,   40,   50,   30,   60,   70,   80,   90,  100,  110,
#   170,  200,  130,  190,  220,  250,  160,  140,  260,  270,  240]
# Length: 24, dtype: Int64
# Nilai unik dalam kolom Beras: <IntegerArray>
# [ <NA>, 11150, 11200, 11250, 11300, 11350, 11400, 11450, 11500, 11000, 11100,
#  11750, 11850, 11950, 11550, 11600, 11650, 11700, 11800, 11900, 12050, 12100,
#  12150, 12300, 12350, 12400, 12450, 12500, 12600, 12550, 12750, 12800, 12850,
#  12950, 13050, 13400, 13600, 13650, 13700, 13750, 13800, 13850, 13900, 13950,
#  14000, 14050, 14100, 14150, 14250, 14300, 14450, 14500, 14550, 14650, 14750,
#  14800, 15150, 15250, 15300, 15450, 15500, 15850, 15550, 15600, 15650, 15700,
#  15750, 15800]
# Length: 68, dtype: Int64
# Nilai unik dalam kolom Beras Kualitas Bawah I: <IntegerArray>
# [ <NA>, 10100, 10150, 10200, 10250, 10350, 10400, 10450, 10500, 10550, 10050,
#  10000,  9950, 10300, 10600, 10650, 10700, 10750, 10800, 10850, 10950, 11000,
#  11050, 11100, 11150, 11300, 11350, 11400, 11450, 11500, 11550, 11600, 11650,
#  11700, 11850, 11900, 11950, 12050, 12200, 12550, 12700, 12750, 12800, 12900,
#  12950, 13000, 13050, 13100, 13150, 13200, 13250, 13350, 13400, 13450, 13600,
#  13650, 13700, 13900, 14000, 14300, 14400, 14550, 14600, 15300, 14700, 14800,
#  14850, 14900, 15050, 15000, 14950]
# Length: 71, dtype: Int64
# Nilai unik dalam kolom Beras Kualitas Medium I: <IntegerArray>
# [ <NA>, 11350, 11400, 11450, 11500, 11600, 11650, 11700, 11550, 11200, 11150,
#  11050, 11750, 11850, 11900, 11950, 12000, 12050, 12100, 12200, 12250, 12300,
#  12500, 12600, 12650, 12750, 12550, 12700, 12900, 12950, 13000, 13150, 13200,
#  13600, 13800, 13850, 13900, 13950, 14000, 14050, 14100, 14150, 14200, 14250,
#  14300, 14500, 14550, 14650, 14700, 14800, 14900, 15000, 15350, 15450, 15700,
#  15750, 16100, 15800, 15900, 15950, 16000, 16050]
# Length: 62, dtype: Int64
# Nilai unik dalam kolom Beras Kualitas Super I: <IntegerArray>
# [ <NA>, 12900, 12950, 13000, 13050, 13100, 13150, 13200, 13250, 12500, 12750,
#  16200, 13300, 13350, 13400, 13450, 13500, 13550, 13600, 13700, 13800, 14000,
#  14050, 14100, 14150, 14200, 14300, 14450, 14250, 14600, 14350, 14400, 14850,
#  15100, 15150, 15200, 15250, 15300, 15350, 15400, 15450, 15500, 15550, 15600,
#  15700, 15750, 15850, 16000, 16050, 16150, 16250, 16600, 16650, 16700, 16800,
#  16950, 17000, 17050, 17150, 17200, 17250, 17300]
# Length: 62, dtype: Int64

# %%
# plt.plot(df3)
df3[['GKP Tingkat Petani']].plot(style='.-', use_index=True)
# df3[['GKP Tingkat Petani']].loc['2020-01-01':'2024-03-01'].plot(style='.-')
plt.tight_layout()
plt.show()

# %%
# Clean dataset df3 from NaN
df3 = df3.dropna()
df3
# Out:
#             Luas Panen Padi  GKP Tingkat Petani  GKP Tingkat Penggilingan  \
# Komoditas
# 2021-03-15               10                4000                      4150
# 2021-03-16               10                3850                      4100
# 2021-03-17               10                4160                      4230
# 2021-03-18               10                4120                      4190
# 2021-03-19               10                4190                      4290
# ...                     ...                 ...                       ...
# 2024-03-11               10                6760                      7140
# 2024-03-12               10                6530                      6930
# 2024-03-13               10                6480                      6920
# 2024-03-14               10                6510                      7060
# 2024-03-15               10                6480                      6930
#
#             GKG Tingkat Penggilingan  Beras Medium Penggilingan  \
# Komoditas
# 2021-03-15                      5050                       8900
# 2021-03-16                      4740                       8740
# 2021-03-17                      4950                       8740
# 2021-03-18                      4730                       8790
# 2021-03-19                      4990                       8830
# ...                              ...                        ...
# 2024-03-11                      8330                      14180
# 2024-03-12                      8260                      14140
# 2024-03-13                      8240                      14040
# 2024-03-14                      8240                      14050
# 2024-03-15                      8190                      14120
#
#             Beras Premium Penggilingan  Stok GKG Tingkat Penggilingan  \
# Komoditas
# 2021-03-15                       10030                             20
# 2021-03-16                        9980                             70
# 2021-03-17                       10060                             30
# 2021-03-18                        9890                             40
# 2021-03-19                        9990                             40
# ...                                ...                            ...
# 2024-03-11                       15640                            120
# 2024-03-12                       15480                            120
# 2024-03-13                       15460                            100
# 2024-03-14                       15510                            150
# 2024-03-15                       15470                            150
#
#             Stok Beras Tingkat Penggilingan  Beras  Beras Kualitas Bawah I  \
# Komoditas
# 2021-03-15                               10  11200                   10100
# 2021-03-16                               20  11200                   10100
# 2021-03-17                               10  11200                   10100
# 2021-03-18                               10  11200                   10050
# 2021-03-19                               10  11200                   10100
# ...                                     ...    ...                     ...
# 2024-03-11                               80  15800                   14950
# 2024-03-12                               80  15800                   14950
# 2024-03-13                               60  15750                   14900
# 2024-03-14                               70  15750                   14900
# 2024-03-15                               80  15750                   14950
#
#             Beras Kualitas Medium I  Beras Kualitas Super I
# Komoditas
# 2021-03-15                    11450                   13100
# 2021-03-16                    11450                   13100
# 2021-03-17                    11450                   13100
# 2021-03-18                    11450                   13100
# 2021-03-19                    11450                   13100
# ...                             ...                     ...
# 2024-03-11                    16050                   17250
# 2024-03-12                    16050                   17250
# 2024-03-13                    16000                   17200
# 2024-03-14                    16000                   17200
# 2024-03-15                    16000                   17200
#
# [733 rows x 12 columns]

# %%
plt.plot(df3)
# df3[['GKP Tingkat Petani']].plot(style='.-', use_index=True)
# df3[['GKP Tingkat Petani']].loc['2020-01-01':'2024-03-01'].plot(style='.-')
plt.tight_layout()
plt.show()

# %%
# Show me the column names of df3 in the plot above
df3.columns
import matplotlib.pyplot as plt

# Plot the dataframe
df3.plot()

# Show the column names
plt.legend(df3.columns)

# Display the plot
plt.show()

# %%
#Membuat fungsi untuk uji stasioneritas
def test_stationarity(timeseries):

    #Determing rolling statistics
    rolmean = timeseries.rolling( window=12).mean()
    rolstd = timeseries.rolling( window=12).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()


    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
#Menguji data
test_stationarity(df3['Beras'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   1.464749
# p-value                          0.997389
# #Lags Used                       8.000000
# Number of Observations Used    724.000000
# Critical Value (1%)             -3.439414
# Critical Value (5%)             -2.865540
# Critical Value (10%)            -2.568900
# dtype: float64

# %%
#Melakukan differencing pertama
df3_diff_1 = df3 - df3.shift()
df3_diff_1 = df3_diff_1.dropna()
plt.plot(df3_diff_1)
# Out:
# [<matplotlib.lines.Line2D at 0x166c53610>,
#  <matplotlib.lines.Line2D at 0x166c46dd0>,
#  <matplotlib.lines.Line2D at 0x166c3bdd0>,
#  <matplotlib.lines.Line2D at 0x166c6c1d0>,
#  <matplotlib.lines.Line2D at 0x166c6c510>,
#  <matplotlib.lines.Line2D at 0x166c0c9d0>,
#  <matplotlib.lines.Line2D at 0x166c44cd0>,
#  <matplotlib.lines.Line2D at 0x166b15010>,
#  <matplotlib.lines.Line2D at 0x166c6d350>,
#  <matplotlib.lines.Line2D at 0x166c296d0>,
#  <matplotlib.lines.Line2D at 0x166c05d10>,
#  <matplotlib.lines.Line2D at 0x166c6e050>]

# %%
#Mencoba melakukan transformasi log
df3_log_dif = np.log(df3_diff_1)
plt.plot(df3_log_dif)
# Out:
# /Library/miniconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:670: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs2, **kwargs)
# /Library/miniconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:670: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs2, **kwargs)
# [<matplotlib.lines.Line2D at 0x166d23a50>,
#  <matplotlib.lines.Line2D at 0x166d23fd0>,
#  <matplotlib.lines.Line2D at 0x166bac550>,
#  <matplotlib.lines.Line2D at 0x166d6c850>,
#  <matplotlib.lines.Line2D at 0x166d6ccd0>,
#  <matplotlib.lines.Line2D at 0x166d6d1d0>,
#  <matplotlib.lines.Line2D at 0x166d6d610>,
#  <matplotlib.lines.Line2D at 0x166d6da50>,
#  <matplotlib.lines.Line2D at 0x166d6ded0>,
#  <matplotlib.lines.Line2D at 0x166be6450>,
#  <matplotlib.lines.Line2D at 0x166d6e750>,
#  <matplotlib.lines.Line2D at 0x166c9ecd0>]

# %%
#Mencoba melakukan transformasi log
df3_log = np.log(df3)
plt.plot(df3_log)
# Out:
# /Library/miniconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:670: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs2, **kwargs)
# [<matplotlib.lines.Line2D at 0x166df7c90>,
#  <matplotlib.lines.Line2D at 0x166e4c150>,
#  <matplotlib.lines.Line2D at 0x166def6d0>,
#  <matplotlib.lines.Line2D at 0x166e4c9d0>,
#  <matplotlib.lines.Line2D at 0x166df4ed0>,
#  <matplotlib.lines.Line2D at 0x166e4d250>,
#  <matplotlib.lines.Line2D at 0x166d8d790>,
#  <matplotlib.lines.Line2D at 0x166c95bd0>,
#  <matplotlib.lines.Line2D at 0x166c06010>,
#  <matplotlib.lines.Line2D at 0x166be6410>,
#  <matplotlib.lines.Line2D at 0x166e4e6d0>,
#  <matplotlib.lines.Line2D at 0x166da6c10>]

# %%
#Melakukan differencing setelah transform log
df3_log_1 = df3_log - df3_log.shift()
df3_log_1 = df3_log_1.dropna()
plt.plot(df3_log_1)
# Out:
# [<matplotlib.lines.Line2D at 0x166d907d0>,
#  <matplotlib.lines.Line2D at 0x166f38090>,
#  <matplotlib.lines.Line2D at 0x166f38690>,
#  <matplotlib.lines.Line2D at 0x166f38990>,
#  <matplotlib.lines.Line2D at 0x166f38d90>,
#  <matplotlib.lines.Line2D at 0x166f39290>,
#  <matplotlib.lines.Line2D at 0x166ed97d0>,
#  <matplotlib.lines.Line2D at 0x166f39b10>,
#  <matplotlib.lines.Line2D at 0x166e72090>,
#  <matplotlib.lines.Line2D at 0x166f3a550>,
#  <matplotlib.lines.Line2D at 0x166f3a810>,
#  <matplotlib.lines.Line2D at 0x166eaad90>]

# %%
# Assuming 'column_name' is the name of the column in df3_log_1
test_stationarity(df3_log_1['Stok Beras Tingkat Penggilingan'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.393318e+01
# p-value                        5.045999e-26
# #Lags Used                     7.000000e+00
# Number of Observations Used    7.240000e+02
# Critical Value (1%)           -3.439414e+00
# Critical Value (5%)           -2.865540e+00
# Critical Value (10%)          -2.568900e+00
# dtype: float64

# %%
#Melakukan differencing kedua
df3_log_2 = df3_log_1 - df3_log_1.shift()
df3_log_2 = df3_log_2.dropna()
plt.plot(df3_log_2)
# Out:
# [<matplotlib.lines.Line2D at 0x167900bd0>,
#  <matplotlib.lines.Line2D at 0x166ea9150>,
#  <matplotlib.lines.Line2D at 0x167900610>,
#  <matplotlib.lines.Line2D at 0x167901950>,
#  <matplotlib.lines.Line2D at 0x1678d9ed0>,
#  <matplotlib.lines.Line2D at 0x167902290>,
#  <matplotlib.lines.Line2D at 0x1678ca790>,
#  <matplotlib.lines.Line2D at 0x167902bd0>,
#  <matplotlib.lines.Line2D at 0x1678ab010>,
#  <matplotlib.lines.Line2D at 0x1678c2310>,
#  <matplotlib.lines.Line2D at 0x1678c3850>,
#  <matplotlib.lines.Line2D at 0x1678abc90>]

# %%
# Assuming 'column_name' is the name of the column in df3_log_2
test_stationarity(df3_log_2['Stok Beras Tingkat Penggilingan'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.096788e+01
# p-value                        8.017574e-20
# #Lags Used                     2.000000e+01
# Number of Observations Used    7.100000e+02
# Critical Value (1%)           -3.439594e+00
# Critical Value (5%)           -2.865619e+00
# Critical Value (10%)          -2.568942e+00
# dtype: float64

# %%
plt.figure()
plt.subplot(211)
plot_acf(df3_log_2['Stok Beras Tingkat Penggilingan'], ax=plt.gca(), lags=12)
plt.subplot(212)
plot_pacf(df3_log_2['Stok Beras Tingkat Penggilingan'], ax=plt.gca(), lags=12)
plt.show()

# %%
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	X = X.astype('float32')
	train_size = int(len(X) * 0.7)               #data trainingnya 70%
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %%
p_values = range(0, 3)
d_values = range(0, 2)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(df3_log['Stok GKG Tingkat Penggilingan'].values, p_values, d_values, q_values)
# Out:
# Best ARIMANone RMSE=inf

# %%
from statsmodels.tsa.arima.model import ARIMA

model_ARIMA = ARIMA(df3_log['Stok Beras Tingkat Penggilingan'], order=(2,1,1))
results_ARIMA = model_ARIMA.fit()
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
plt.plot(df3_log_2['Stok Beras Tingkat Penggilingan'])
plt.plot(predictions_ARIMA_diff, color='red')

import warnings

with warnings.catch_warnings():
    warnings.filterwarnings("ignore")
    results_ARIMA = model_ARIMA.fit()

# %%
predictions_ARIMA_diff_cum_sum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_log = pd.Series(df3_log.iloc[6],index=df3_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cum_sum,fill_value=0)
plt.plot(df3_log)
plt.plot(predictions_ARIMA_log, color='red')               #fitting dengan data yang ditransformasi log

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(df3)
plt.plot(predictions_ARIMA, color='red')                    #fitting dengan data asli

# %%
results_ARIMA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:     Stok Beras Tingkat Penggilingan   No. Observations:                  733
# Model:                              ARIMA(2, 1, 1)   Log Likelihood                -210.174
# Date:                             Wed, 20 Mar 2024   AIC                            428.348
# Time:                                     13:20:30   BIC                            446.732
# Sample:                                          0   HQIC                           435.440
#                                              - 733
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2090      0.040      5.255      0.000       0.131       0.287
# ar.L2          0.1528      0.041      3.751      0.000       0.073       0.233
# ma.L1         -0.8516      0.030    -27.947      0.000      -0.911      -0.792
# sigma2         0.1039      0.004     26.973      0.000       0.096       0.111
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               134.11
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.21   Skew:                             0.31
# Prob(H) (two-sided):                  0.15   Kurtosis:                         5.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train_size = int(len(df3) * 0.7)               #data trainingnya 70%
train, test = df3_log_2[:train_size], df3_log_2[train_size:]
history = [x for x in train['Stok Beras Tingkat Penggilingan']]
# make predictions
predictions = list()
for t in range(len(test)):
    model = SARIMAX(history, order=(1,1,1), seasonal_order=(1,1,1,4))
    model_fit = model.fit(method='bfgs', maxiter=200)
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    history.append(test['Stok Beras Tingkat Penggilingan'].iloc[t])

# calculate out of sample error
rmse = sqrt(mean_squared_error(test['Stok Beras Tingkat Penggilingan'], predictions))
print(rmse)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.701022
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.700112
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.699343
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.698994
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.698875
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.698139
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.701488
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.702676
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.703325
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.702365
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.702402
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.701625
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.700978
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.699991
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.699006
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.698023
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.697816
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.698043
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.697193
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.696493
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.696241
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.695435
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.696339
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.695459
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.694665
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.693701
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.692743
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.692496
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.691637
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.690995
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.690041
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.689088
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.688139
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.687191
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.686245
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.685299
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.685164
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.685411
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.684584
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.683921
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.682983
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.682056
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.681121
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.680195
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.680058
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.679198
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.680282
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.679409
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.680362
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.680552
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.680002
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.679135
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.678593
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.677687
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.677568
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.677687
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.676931
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.677853
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.677035
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.676305
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.675401
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.674515
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.674188
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.674656
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.673810
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.678642
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.684025
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.683497
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.684312
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.683805
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.683697
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.682878
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.682228
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.681349
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.680472
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.679592
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.679344
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.678535
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.677965
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.677092
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.676899
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.676109
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.675852
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.675154
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.679976
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.682411
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.682414
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.681715
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.681978
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.682544
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.684574
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.684599
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.683880
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.684104
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.683277
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.684295
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.686302
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.685739
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.685676
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.686226
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.685441
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.689302
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.691178
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.690430
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.690245
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690589
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.689808
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.689612
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690875
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690119
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690222
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.689411
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.688589
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.687769
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.686947
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.686126
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.685306
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.684487
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.683669
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.682853
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.682039
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.682836
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.684918
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.684269
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.688021
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690746
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690978
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690709
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.691983
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.692649
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.692082
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.691449
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.691204
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690621
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.689858
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.689275
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.688663
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.689156
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.688529
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.688030
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.689219
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.690428
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.689778
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.689087
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.688394
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.688014
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.687234
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.686772
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.686048
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.685400
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.684622
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.683844
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.683068
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.683196
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.684053
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.683300
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.682793
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.682022
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.681489
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.681266
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.680714
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.680095
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.679330
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.678566
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.677804
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.678658
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.681000
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.686028
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.685519
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.685299
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.690457
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.690319
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.691548
#          Iterations: 37
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.691301
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.690554
#          Iterations: 37
#          Function evaluations: 40
#          Gradient evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.689811
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.690360
#          Iterations: 41
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.691221
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.695493
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.701839
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.701223
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.702445
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.707709
#          Iterations: 38
#          Function evaluations: 41
#          Gradient evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.710431
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.710921
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.710571
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.712068
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.711672
#          Iterations: 43
#          Function evaluations: 46
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: 0.710993
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.710262
#          Iterations: 43
#          Function evaluations: 46
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: 0.709554
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.709066
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.708356
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.709348
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.710264
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.709897
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.709210
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.709657
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.709018
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.708560
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.707869
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.707201
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.706906
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.706286
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.705566
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.704991
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.706812
#          Iterations: 43
#          Function evaluations: 46
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: 0.721141
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.720601
#          Iterations: 40
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.722355
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.721752
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.721247
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.720783
#          Iterations: 43
#          Function evaluations: 46
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: 0.720527
#          Iterations: 43
#          Function evaluations: 46
#          Gradient evaluations: 46
# Optimization terminated successfully.
#          Current function value: 0.719879
#          Iterations: 42
#          Function evaluations: 45
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 0.719237
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.718625
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.718150
#          Iterations: 39
#          Function evaluations: 42
#          Gradient evaluations: 42
# 0.5148780337903689

# %% [markdown]
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     42     70      1     0     0   6.124D-04   7.182D-01
#   F =  0.71815758056793100
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# 0.5148244027324439

# %%
#explain the the result of the model
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                  730
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 4)   Log Likelihood                -524.250
# Date:                           Wed, 20 Mar 2024   AIC                           1058.499
# Time:                                   13:22:14   BIC                           1081.430
# Sample:                                        0   HQIC                          1067.349
#                                            - 730
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6759      0.025    -27.499      0.000      -0.724      -0.628
# ma.L1         -1.0000     11.132     -0.090      0.928     -22.819      20.819
# ar.S.L4        0.0356      0.031      1.137      0.256      -0.026       0.097
# ma.S.L4       -1.0000     15.006     -0.067      0.947     -30.412      28.412
# sigma2         0.2366      4.357      0.054      0.957      -8.304       8.777
# ===================================================================================
# Ljung-Box (L1) (Q):                  58.97   Jarque-Bera (JB):                76.52
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.11
# Prob(H) (two-sided):                  0.64   Kurtosis:                         4.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#Bikin model SARIMA
model_sarima = SARIMAX(df3_log_2['Stok Beras Tingkat Penggilingan'], order=(1,1,1), seasonal_order=(1,1,1,4))
results_SARIMA = model_sarima.fit(disp=-1)
predictions_SARIMA_diff = pd.Series(results_SARIMA.fittedvalues,copy=True)
plt.plot(df3_log_2['Stok Beras Tingkat Penggilingan'])
plt.plot(predictions_SARIMA_diff, color='red')               #fitting dengan data log

# %%
#SARIMA + trend untuk data asli
model_sarima_trend = SARIMAX(df3['Stok Beras Tingkat Penggilingan'], order=(1,1,1), seasonal_order=(1,1,1,4), trend='t')
results_SARIMA_t = model_sarima_trend.fit(disp=-1)
predictions_SARIMA_diff_t = pd.Series(results_SARIMA_t.fittedvalues,copy=True)
plt.plot(df3['Stok Beras Tingkat Penggilingan'])
plt.plot(predictions_SARIMA_diff_t, color='red')               #fitting dengan data

# %%
results_SARIMA_t.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:     Stok Beras Tingkat Penggilingan   No. Observations:                  733
# Model:               SARIMAX(1, 1, 1)x(1, 1, 1, 4)   Log Likelihood               -3213.065
# Date:                             Wed, 20 Mar 2024   AIC                           6438.131
# Time:                                     13:22:15   BIC                           6465.672
# Sample:                                          0   HQIC                          6448.758
#                                              - 733
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift       6.245e-07    7.7e-06      0.081      0.935   -1.45e-05    1.57e-05
# ar.L1          0.4676      0.030     15.667      0.000       0.409       0.526
# ma.L1         -0.9397      0.014    -65.907      0.000      -0.968      -0.912
# ar.S.L4        0.0288      0.055      0.527      0.598      -0.078       0.136
# ma.S.L4       -0.9759      0.031    -31.532      0.000      -1.037      -0.915
# sigma2       637.5037     20.296     31.410      0.000     597.724     677.283
# ===================================================================================
# Ljung-Box (L1) (Q):                  12.06   Jarque-Bera (JB):             28107.14
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               8.24   Skew:                             2.76
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#dengan model ARIMA
predict_dif = results_ARIMA.predict(start=144,end=156)
predictions_dif_cum_sum = predict_dif.cumsum()                   #prediksi differencingnya
pred_log = [df3_log_2['Stok Beras Tingkat Penggilingan'].iloc[-1]]
for i, j in enumerate(predictions_dif_cum_sum):                  #prediksi data lognya
  a = pred_log[i] + j
  pred_log.append(a)
predict_exp = pd.Series(np.exp(pred_log[1:]), index=predict_dif.index)  #prediksi data aslinya
print(predict_exp)
# Out:
# Komoditas
# 2021-10-15     2.871092e+01
# 2021-10-18     2.474872e+04
# 2021-10-19     6.292750e+08
# 2021-10-21     4.093291e+14
# 2021-10-22     6.172739e+21
# 2021-10-25     2.704660e+30
# 2021-10-26     3.621828e+40
# 2021-10-27     1.223797e+52
# 2021-10-28     9.474876e+64
# 2021-10-29     1.904077e+79
# 2021-11-01     1.079640e+95
# 2021-11-02    1.743048e+112
# 2021-11-03    8.074988e+130
# dtype: float64

# %%
#prediksi dengan SARIMA+trend
pred_2 = results_SARIMA_t.predict()
print(pred_2)
# Out:
# Komoditas
# 2021-03-15     0.000001
# 2021-03-16     9.998219
# 2021-03-17    19.995969
# 2021-03-18    10.003183
# 2021-03-19    15.000761
#                 ...
# 2024-03-11    91.842013
# 2024-03-12    80.465562
# 2024-03-13    88.252290
# 2024-03-14    70.284883
# 2024-03-15    79.784194
# Name: predicted_mean, Length: 733, dtype: float64

# %%
df3
# Out:
#             Luas Panen Padi  GKP Tingkat Petani  GKP Tingkat Penggilingan  \
# Komoditas
# 2021-03-15               10                4000                      4150
# 2021-03-16               10                3850                      4100
# 2021-03-17               10                4160                      4230
# 2021-03-18               10                4120                      4190
# 2021-03-19               10                4190                      4290
# ...                     ...                 ...                       ...
# 2024-03-11               10                6760                      7140
# 2024-03-12               10                6530                      6930
# 2024-03-13               10                6480                      6920
# 2024-03-14               10                6510                      7060
# 2024-03-15               10                6480                      6930
#
#             GKG Tingkat Penggilingan  Beras Medium Penggilingan  \
# Komoditas
# 2021-03-15                      5050                       8900
# 2021-03-16                      4740                       8740
# 2021-03-17                      4950                       8740
# 2021-03-18                      4730                       8790
# 2021-03-19                      4990                       8830
# ...                              ...                        ...
# 2024-03-11                      8330                      14180
# 2024-03-12                      8260                      14140
# 2024-03-13                      8240                      14040
# 2024-03-14                      8240                      14050
# 2024-03-15                      8190                      14120
#
#             Beras Premium Penggilingan  Stok GKG Tingkat Penggilingan  \
# Komoditas
# 2021-03-15                       10030                             20
# 2021-03-16                        9980                             70
# 2021-03-17                       10060                             30
# 2021-03-18                        9890                             40
# 2021-03-19                        9990                             40
# ...                                ...                            ...
# 2024-03-11                       15640                            120
# 2024-03-12                       15480                            120
# 2024-03-13                       15460                            100
# 2024-03-14                       15510                            150
# 2024-03-15                       15470                            150
#
#             Stok Beras Tingkat Penggilingan  Beras  Beras Kualitas Bawah I  \
# Komoditas
# 2021-03-15                               10  11200                   10100
# 2021-03-16                               20  11200                   10100
# 2021-03-17                               10  11200                   10100
# 2021-03-18                               10  11200                   10050
# 2021-03-19                               10  11200                   10100
# ...                                     ...    ...                     ...
# 2024-03-11                               80  15800                   14950
# 2024-03-12                               80  15800                   14950
# 2024-03-13                               60  15750                   14900
# 2024-03-14                               70  15750                   14900
# 2024-03-15                               80  15750                   14950
#
#             Beras Kualitas Medium I  Beras Kualitas Super I
# Komoditas
# 2021-03-15                    11450                   13100
# 2021-03-16                    11450                   13100
# 2021-03-17                    11450                   13100
# 2021-03-18                    11450                   13100
# 2021-03-19                    11450                   13100
# ...                             ...                     ...
# 2024-03-11                    16050                   17250
# 2024-03-12                    16050                   17250
# 2024-03-13                    16000                   17200
# 2024-03-14                    16000                   17200
# 2024-03-15                    16000                   17200
#
# [733 rows x 12 columns]

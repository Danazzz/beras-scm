# %%
import pandas as pd
import zipfile, os
import numpy as np
import csv
import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import STL

# %%
# Specify the path to your CSV file
# !wget https://raw.githubusercontent.com/Danazzz/dataset-beras-scm/master/csv/Beras.csv

df_beras = pd.read_csv('Beras.csv')
df_beras
# Out:
# --2024-06-11 18:14:25--  https://raw.githubusercontent.com/Danazzz/dataset-beras-scm/master/csv/Beras.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42658 (42K) [text/plain]
# Saving to: ‘Beras.csv.9’
#
# Beras.csv.9         100%[===================>]  41.66K  --.-KB/s    in 0.01s
#
# 2024-06-11 18:14:25 (3.57 MB/s) - ‘Beras.csv.9’ saved [42658/42658]
#         Tanggal  Luas Panen Padi  GKP Tingkat Petani  \
# 0    2021-03-15               10                4000
# 1    2021-03-16               10                3850
# 2    2021-03-17               10                4160
# 3    2021-03-18               10                4120
# 4    2021-03-19               10                4190
# ..          ...              ...                 ...
# 673  2023-12-21               30                6770
# 674  2023-12-22               30                6600
# 675  2023-12-27               30                6620
# 676  2023-12-28               30                6650
# 677  2023-12-29               30                6730
#
#      GKP Tingkat Penggilingan  GKG Tingkat Penggilingan  \
# 0                        4150                      5050
# 1                        4100                      4740
# 2                        4230                      4950
# 3                        4190                      4730
# 4                        4290                      4990
# ..                        ...                       ...
# 673                      6850                      7980
# 674                      6760                      8050
# 675                      6760                      8030
# 676                      6760                      8020
# 677                      6820                      8100
#
#      Harga Beras Penggilingan  Produksi Beras  Harga Beras   UMP  BBM Solar  \
# 0                        9465           14419        11200  4960       9600
# 1                        9360           14419        11200  4960       9600
# 2                        9400           14419        11200  4960       9600
# 3                        9340           14419        11200  4960       9600
# 4                        9410           14419        11200  4960       9600
# ..                        ...             ...          ...   ...        ...
# 673                     13100           14391        14000  5444       6800
# 674                     13095           14391        14000  5444       6800
# 675                     13120           14391        14000  5444       6800
# 676                     13120           14391        14000  5444       6800
# 677                     13150           14391        14000  5444       6800
#
#      Tingkat Konsumsi
# 0               17161
# 1               17161
# 2               17161
# 3               17161
# 4               17161
# ..                ...
# 673             17598
# 674             17598
# 675             17598
# 676             17598
# 677             17598
#
# [678 rows x 11 columns]

# %%
# stl = STL(df_beras['Harga Beras'], period=12, robust=True)
# result = stl.fit()
# fig = result.plot()

# %%
df_beras.drop(['Tanggal'], axis = 1, inplace = True)

# %%
df_beras_trend = pd.DataFrame()
df_beras_seasonal = pd.DataFrame()
df_beras_resid = pd.DataFrame()

for series_name, series in df_beras.items():
  stl = STL(df_beras[series_name], period=12, robust=True)
  result = stl.fit()
  df_beras_trend[series_name] = result.trend
  df_beras_seasonal[series_name] = result.seasonal
  df_beras_resid[series_name] = result.resid

# %%
def data_to_X_y(df, window_size=3):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size][6]
    y.append(label)
  return np.array(X), np.array(y)

X_trend, y_trend = data_to_X_y(df_beras_trend)
X_seasonal, y_seasonal = data_to_X_y(df_beras_seasonal)
X_resid, y_resid = data_to_X_y(df_beras_resid)
X_trend.shape
# Out:
# (675, 3, 10)

# %%
# # WINDOW_SIZE = 3
# X_trend, y_trend = df_to_X_y(result.trend)
# X_seasonal, y_seasonal = df_to_X_y(result.seasonal)
# X_resid, y_resid = df_to_X_y(result.resid)
# X_trend.shape, y_trend.shape

# %%
def split_data(X, y):
  q_80 = int(len(X) * .8)

  X_train, y_train = X[:q_80], y[:q_80]
  X_test, y_test = X[q_80:], y[q_80:]
  X_train.shape, y_train.shape, X_test.shape, y_test.shape

  return X_train, y_train, X_test, y_test

# %%
X_train_trend, y_train_trend, X_test_trend, y_test_trend = split_data(X_trend, y_trend)
X_train_seasonal, y_train_seasonal, X_test_seasonal, y_test_seasonal = split_data(X_seasonal, y_seasonal)
X_train_resid, y_train_resid, X_test_resid, y_test_resid = split_data(X_resid, y_resid)

# %%
y_test_trend
# Out:
# array([12421.60656452, 12421.84076624, 12421.95986709, 12421.92481015,
#        12421.77919263, 12421.58810954, 12421.38690935, 12421.17616695,
#        12420.93984769, 12420.68770403, 12420.4542889 , 12420.24778023,
#        12420.04576115, 12419.84786501, 12419.71470897, 12419.70712492,
#        12419.90965437, 12420.30052265, 12420.84128974, 12421.73001443,
#        12423.2694792 , 12425.76012651, 12429.36506994, 12433.64228586,
#        12437.94657357, 12442.4612124 , 12447.48419259, 12453.15619406,
#        12463.40317629, 12486.74755836, 12505.98814779, 12518.32390212,
#        12528.77482027, 12539.49362202, 12553.56972422, 12569.00501254,
#        12583.85379816, 12597.20163968, 12609.077213  , 12637.14789466,
#        12673.30623345, 12721.55654102, 12778.13650501, 12831.74789502,
#        12885.33250092, 12937.81792941, 12989.30427619, 13040.00309546,
#        13089.56383983, 13136.20429017, 13174.80035571, 13225.05794684,
#        13287.77678273, 13350.49967802, 13413.22934306, 13475.97199137,
#        13538.73517792, 13601.5283507 , 13572.64954856, 13585.05410871,
#        13617.3271102 , 13651.2291102 , 13687.02351809, 13737.16704633,
#        13851.63197943, 13916.24041541, 13918.68404155, 13920.80826652,
#        13922.89154149, 13925.0397599 , 13927.24645094, 13929.46892188,
#        13931.68363521, 13933.88219636, 13936.01952496, 13937.96393054,
#        13939.74160473, 13941.36219719, 13942.92537944, 13944.53363952,
#        13946.1279114 , 13947.64174367, 13948.97216748, 13950.07334239,
#        13950.87776779, 13951.49509963, 13951.90403346, 13952.03677617,
#        13952.02010056, 13951.88916677, 13951.66541653, 13951.39859045,
#        13951.08728861, 13950.7259028 , 13950.34020455, 13949.99262845,
#        13949.72303901, 13949.48898629, 13949.24734701, 13948.96703254,
#        13948.63240641, 13948.2774044 , 13947.98415476, 13947.86757135,
#        13947.87647334, 13947.87218395, 13947.79456336, 13947.68608866,
#        13947.68585854, 13947.94080933, 13948.46388339, 13949.01766181,
#        13949.31327925, 13949.1842829 , 13948.90004384, 13949.68943159,
#        13951.71571198, 13954.33210128, 13957.34137902, 13960.63080196,
#        13964.11629265, 13967.78303716, 13971.66348277, 13975.74751595,
#        13979.9437838 , 13984.14633176, 13988.35543135, 13992.57056838,
#        13996.79022678, 14001.01245763, 14005.2359141 , 14009.4598585 ,
#        14013.68387945, 14017.90788318, 14022.1314738 ])

# %%
# from sklearn.preprocessing import MinMaxScaler
# trend_scaler = MinMaxScaler(feature_range=(-1,1))
# seasonal_scaler = MinMaxScaler(feature_range=(-1,1))
# resid_scaler = MinMaxScaler(feature_range=(-1,1))

# def scaling_data(scaler, X_train, y_train, X_test, y_test):
#   X_train = scaler.fit_transform(X_train.reshape(X_train.shape[0], -1)).reshape(X_train.shape)
#   X_test = scaler.transform(X_test.reshape(X_train.shape[0], -1)).reshape(X_test.shape)
#   y_train = scaler.fit_transform(y_train.reshape(-1,1))
#   y_test = scaler.transform(y_test.reshape(-1,1))

#   return X_train, y_train, X_test, y_test

from sklearn.preprocessing import MinMaxScaler
trend_scaler = MinMaxScaler(feature_range=(-1,1))
seasonal_scaler = MinMaxScaler(feature_range=(-1,1))
resid_scaler = MinMaxScaler(feature_range=(-1,1))
# X_trend_scaler = MinMaxScaler(feature_range=(-1,1))
# y_trend_scaler = MinMaxScaler(feature_range=(-1,1))
# X_seasonal_scaler = MinMaxScaler(feature_range=(-1,1))
# y_seasonal_scaler = MinMaxScaler(feature_range=(-1,1))
# X_resid_scaler = MinMaxScaler(feature_range=(-1,1))
# y_resid_scaler = MinMaxScaler(feature_range=(-1,1))

def scaling_data(scaler, X_train, X_test, y_train, y_test):
  X_train = scaler.fit_transform(X_train.reshape(X_train.shape[0], -1)).reshape(X_train.shape)
  X_test = scaler.transform(X_test.reshape(X_test.shape[0], -1)).reshape(X_test.shape)

  y_train = scaler.fit_transform(y_train.reshape(-1,1))
  y_test = scaler.transform(y_test.reshape(-1,1))

  return X_train, X_test, y_train, y_test

# def X_scaling_data(scaler, X_train, X_test):
#   X_train = scaler.fit_transform(np.array(X_train).reshape(X_train.shape[0], -1))
#   X_test = scaler.transform(np.array(X_test).reshape(X_test.shape[0], -1))
#   return X_train, X_test

# def y_scaling_data(scaler, y_train, y_test):
#   y_train = scaler.fit_transform(np.array(y_train).reshape(-1,1))
#   y_test = scaler.transform(np.array(y_test).reshape(-1,1))
#   return y_train, y_test

X_train_trend, X_test_trend, y_train_trend, y_test_trend = scaling_data(trend_scaler, X_train_trend, X_test_trend, y_train_trend, y_test_trend)
X_train_seasonal, X_test_seasonal, y_train_seasonal, y_test_seasonal = scaling_data(seasonal_scaler, X_train_seasonal, X_test_seasonal, y_train_seasonal, y_test_seasonal)
X_train_resid, X_test_resid, y_train_resid, y_test_resid = scaling_data(resid_scaler, X_train_resid, X_test_resid, y_train_resid, y_test_resid)
# X_train_trend, X_test_trend = X_scaling_data(X_trend_scaler, X_train_trend, X_test_trend)
# y_train_trend, y_test_trend = y_scaling_data(y_trend_scaler, y_train_trend, y_test_trend)
# X_train_seasonal, X_test_seasonal = X_scaling_data(X_seasonal_scaler, X_train_seasonal, X_test_seasonal)
# y_train_seasonal, y_test_seasonal = y_scaling_data(y_seasonal_scaler, y_train_seasonal, y_test_seasonal)
# X_train_resid, X_test_resid = X_scaling_data(X_resid_scaler, X_train_resid, X_test_resid)
# y_train_resid, y_test_resid = y_scaling_data(y_resid_scaler, y_train_resid, y_test_resid)

# %%
X_train_trend.shape
# Out:
# (540, 3, 10)

# %%
# X_train_trend, y_train_trend, X_test_trend, y_test_trend = scaling_data(trend_scaler, X_train_trend, y_train_trend, X_test_trend, y_test_trend)
# X_train_seasonal, y_train_seasonal, X_test_seasonal, y_test_seasonal = scaling_data(seasonal_scaler, X_train_seasonal, y_train_seasonal, X_test_seasonal, y_test_seasonal)
# X_train_resid, y_train_resid, X_test_resid, y_test_resid = scaling_data(resid_scaler, X_train_resid, y_train_resid, X_test_resid, y_test_resid)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

def modelling_data(X_train, y_train):
  model = Sequential([layers.Input((3, 10)),
                      layers.GRU(64),
                      layers.Dense(32, activation='relu'),
                      layers.Dense(32, activation='relu'),
                      layers.Dense(1)])

  model.compile(loss='mse',
                optimizer=Adam(learning_rate=0.0001),
                metrics=['mean_absolute_error'])

  model.fit(X_train, y_train, epochs=100)
  return model

# %%
model_trend = modelling_data(X_train_trend, y_train_trend)
model_seasonal = modelling_data(X_train_seasonal, y_train_seasonal)
model_resid = modelling_data(X_train_resid, y_train_resid)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 3s 4ms/step - loss: 0.4814 - mean_absolute_error: 0.6441
# Epoch 2/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3606 - mean_absolute_error: 0.5541
# Epoch 3/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2619 - mean_absolute_error: 0.4655
# Epoch 4/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1836 - mean_absolute_error: 0.3785
# Epoch 5/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1227 - mean_absolute_error: 0.2899
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0827 - mean_absolute_error: 0.2124
# Epoch 7/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0591 - mean_absolute_error: 0.1618
# Epoch 8/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0441 - mean_absolute_error: 0.1366
# Epoch 9/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0327 - mean_absolute_error: 0.1167
# Epoch 10/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0242 - mean_absolute_error: 0.1017
# Epoch 11/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0180 - mean_absolute_error: 0.0907
# Epoch 12/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0136 - mean_absolute_error: 0.0816
# Epoch 13/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0107 - mean_absolute_error: 0.0741
# Epoch 14/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0091 - mean_absolute_error: 0.0684
# Epoch 15/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0079 - mean_absolute_error: 0.0634
# Epoch 16/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0072 - mean_absolute_error: 0.0596
# Epoch 17/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0067 - mean_absolute_error: 0.0563
# Epoch 18/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0535
# Epoch 19/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0059 - mean_absolute_error: 0.0515
# Epoch 20/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0056 - mean_absolute_error: 0.0496
# Epoch 21/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0479
# Epoch 22/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0052 - mean_absolute_error: 0.0466
# Epoch 23/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0456
# Epoch 24/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0048 - mean_absolute_error: 0.0448
# Epoch 25/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0046 - mean_absolute_error: 0.0437
# Epoch 26/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0044 - mean_absolute_error: 0.0428
# Epoch 27/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0043 - mean_absolute_error: 0.0421
# Epoch 28/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0412
# Epoch 29/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0039 - mean_absolute_error: 0.0403
# Epoch 30/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0038 - mean_absolute_error: 0.0395
# Epoch 31/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0036 - mean_absolute_error: 0.0392
# Epoch 32/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0035 - mean_absolute_error: 0.0384
# Epoch 33/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0375
# Epoch 34/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0370
# Epoch 35/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0365
# Epoch 36/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0358
# Epoch 37/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0351
# Epoch 38/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0027 - mean_absolute_error: 0.0346
# Epoch 39/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0339
# Epoch 40/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0024 - mean_absolute_error: 0.0333
# Epoch 41/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0325
# Epoch 42/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0321
# Epoch 43/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0316
# Epoch 44/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0309
# Epoch 45/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0304
# Epoch 46/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0299
# Epoch 47/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0292
# Epoch 48/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0289
# Epoch 49/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0284
# Epoch 50/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0277
# Epoch 51/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0273
# Epoch 52/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0268
# Epoch 53/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0265
# Epoch 54/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0258
# Epoch 55/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0253
# Epoch 56/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0248
# Epoch 57/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0248
# Epoch 58/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0239
# Epoch 59/100
# 17/17 [==============================] - 0s 4ms/step - loss: 9.9517e-04 - mean_absolute_error: 0.0232
# Epoch 60/100
# 17/17 [==============================] - 0s 4ms/step - loss: 9.4095e-04 - mean_absolute_error: 0.0230
# Epoch 61/100
# 17/17 [==============================] - 0s 4ms/step - loss: 9.0304e-04 - mean_absolute_error: 0.0226
# Epoch 62/100
# 17/17 [==============================] - 0s 4ms/step - loss: 8.6317e-04 - mean_absolute_error: 0.0222
# Epoch 63/100
# 17/17 [==============================] - 0s 4ms/step - loss: 8.2926e-04 - mean_absolute_error: 0.0217
# Epoch 64/100
# 17/17 [==============================] - 0s 4ms/step - loss: 7.9243e-04 - mean_absolute_error: 0.0213
# Epoch 65/100
# 17/17 [==============================] - 0s 4ms/step - loss: 7.6618e-04 - mean_absolute_error: 0.0211
# Epoch 66/100
# 17/17 [==============================] - 0s 4ms/step - loss: 7.4213e-04 - mean_absolute_error: 0.0204
# Epoch 67/100
# 17/17 [==============================] - 0s 4ms/step - loss: 7.0007e-04 - mean_absolute_error: 0.0203
# Epoch 68/100
# 17/17 [==============================] - 0s 4ms/step - loss: 6.7927e-04 - mean_absolute_error: 0.0201
# Epoch 69/100
# 17/17 [==============================] - 0s 4ms/step - loss: 6.6424e-04 - mean_absolute_error: 0.0196
# Epoch 70/100
# 17/17 [==============================] - 0s 4ms/step - loss: 6.4228e-04 - mean_absolute_error: 0.0195
# Epoch 71/100
# 17/17 [==============================] - 0s 4ms/step - loss: 6.2158e-04 - mean_absolute_error: 0.0192
# Epoch 72/100
# 17/17 [==============================] - 0s 4ms/step - loss: 6.1838e-04 - mean_absolute_error: 0.0188
# Epoch 73/100
# 17/17 [==============================] - 0s 4ms/step - loss: 5.9525e-04 - mean_absolute_error: 0.0186
# Epoch 74/100
# 17/17 [==============================] - 0s 4ms/step - loss: 5.8404e-04 - mean_absolute_error: 0.0184
# Epoch 75/100
# 17/17 [==============================] - 0s 4ms/step - loss: 5.7316e-04 - mean_absolute_error: 0.0183
# Epoch 76/100
# 17/17 [==============================] - 0s 5ms/step - loss: 5.6429e-04 - mean_absolute_error: 0.0181
# Epoch 77/100
# 17/17 [==============================] - 0s 4ms/step - loss: 5.5937e-04 - mean_absolute_error: 0.0179
# Epoch 78/100
# 17/17 [==============================] - 0s 4ms/step - loss: 5.4347e-04 - mean_absolute_error: 0.0178
# Epoch 79/100
# 17/17 [==============================] - 0s 4ms/step - loss: 5.3407e-04 - mean_absolute_error: 0.0176
# Epoch 80/100
# 17/17 [==============================] - 0s 4ms/step - loss: 5.2441e-04 - mean_absolute_error: 0.0174
# Epoch 81/100
# 17/17 [==============================] - 0s 5ms/step - loss: 5.1527e-04 - mean_absolute_error: 0.0172
# Epoch 82/100
# 17/17 [==============================] - 0s 5ms/step - loss: 5.0824e-04 - mean_absolute_error: 0.0170
# Epoch 83/100
# 17/17 [==============================] - 0s 5ms/step - loss: 4.9925e-04 - mean_absolute_error: 0.0169
# Epoch 84/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.8864e-04 - mean_absolute_error: 0.0167
# Epoch 85/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.8147e-04 - mean_absolute_error: 0.0166
# Epoch 86/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.7646e-04 - mean_absolute_error: 0.0165
# Epoch 87/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.7026e-04 - mean_absolute_error: 0.0165
# Epoch 88/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.6159e-04 - mean_absolute_error: 0.0162
# Epoch 89/100
# 17/17 [==============================] - 0s 5ms/step - loss: 4.5937e-04 - mean_absolute_error: 0.0163
# Epoch 90/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.4991e-04 - mean_absolute_error: 0.0159
# Epoch 91/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.4386e-04 - mean_absolute_error: 0.0159
# Epoch 92/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.4081e-04 - mean_absolute_error: 0.0159
# Epoch 93/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.3629e-04 - mean_absolute_error: 0.0159
# Epoch 94/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.3658e-04 - mean_absolute_error: 0.0155
# Epoch 95/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.3375e-04 - mean_absolute_error: 0.0158
# Epoch 96/100
# 17/17 [==============================] - 0s 5ms/step - loss: 4.1703e-04 - mean_absolute_error: 0.0153
# Epoch 97/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.2490e-04 - mean_absolute_error: 0.0155
# Epoch 98/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.1001e-04 - mean_absolute_error: 0.0152
# Epoch 99/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.1438e-04 - mean_absolute_error: 0.0153
# Epoch 100/100
# 17/17 [==============================] - 0s 4ms/step - loss: 4.0919e-04 - mean_absolute_error: 0.0150
# Epoch 1/100
# 17/17 [==============================] - 3s 6ms/step - loss: 0.0444 - mean_absolute_error: 0.1473
# Epoch 2/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0414 - mean_absolute_error: 0.1326
# Epoch 3/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0399 - mean_absolute_error: 0.1236
# Epoch 4/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0390 - mean_absolute_error: 0.1190
# Epoch 5/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0386 - mean_absolute_error: 0.1169
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0381 - mean_absolute_error: 0.1157
# Epoch 7/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0377 - mean_absolute_error: 0.1153
# Epoch 8/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0374 - mean_absolute_error: 0.1146
# Epoch 9/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0370 - mean_absolute_error: 0.1139
# Epoch 10/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0366 - mean_absolute_error: 0.1134
# Epoch 11/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0361 - mean_absolute_error: 0.1128
# Epoch 12/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0358 - mean_absolute_error: 0.1125
# Epoch 13/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0355 - mean_absolute_error: 0.1118
# Epoch 14/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0351 - mean_absolute_error: 0.1114
# Epoch 15/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0349 - mean_absolute_error: 0.1122
# Epoch 16/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0344 - mean_absolute_error: 0.1106
# Epoch 17/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0340 - mean_absolute_error: 0.1099
# Epoch 18/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0337 - mean_absolute_error: 0.1097
# Epoch 19/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0334 - mean_absolute_error: 0.1091
# Epoch 20/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0331 - mean_absolute_error: 0.1084
# Epoch 21/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0328 - mean_absolute_error: 0.1082
# Epoch 22/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0325 - mean_absolute_error: 0.1077
# Epoch 23/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0321 - mean_absolute_error: 0.1069
# Epoch 24/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0318 - mean_absolute_error: 0.1065
# Epoch 25/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0316 - mean_absolute_error: 0.1065
# Epoch 26/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0312 - mean_absolute_error: 0.1055
# Epoch 27/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0310 - mean_absolute_error: 0.1056
# Epoch 28/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0306 - mean_absolute_error: 0.1048
# Epoch 29/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0304 - mean_absolute_error: 0.1045
# Epoch 30/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0301 - mean_absolute_error: 0.1043
# Epoch 31/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0298 - mean_absolute_error: 0.1040
# Epoch 32/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0295 - mean_absolute_error: 0.1038
# Epoch 33/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0293 - mean_absolute_error: 0.1036
# Epoch 34/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0291 - mean_absolute_error: 0.1035
# Epoch 35/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0288 - mean_absolute_error: 0.1031
# Epoch 36/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0286 - mean_absolute_error: 0.1028
# Epoch 37/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0284 - mean_absolute_error: 0.1027
# Epoch 38/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0282 - mean_absolute_error: 0.1026
# Epoch 39/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0280 - mean_absolute_error: 0.1028
# Epoch 40/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0277 - mean_absolute_error: 0.1020
# Epoch 41/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0275 - mean_absolute_error: 0.1016
# Epoch 42/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0273 - mean_absolute_error: 0.1013
# Epoch 43/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0271 - mean_absolute_error: 0.1013
# Epoch 44/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0269 - mean_absolute_error: 0.1008
# Epoch 45/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0267 - mean_absolute_error: 0.1007
# Epoch 46/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0266 - mean_absolute_error: 0.1011
# Epoch 47/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0263 - mean_absolute_error: 0.1006
# Epoch 48/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0262 - mean_absolute_error: 0.1001
# Epoch 49/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0259 - mean_absolute_error: 0.1000
# Epoch 50/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0258 - mean_absolute_error: 0.1000
# Epoch 51/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0256 - mean_absolute_error: 0.0996
# Epoch 52/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0255 - mean_absolute_error: 0.0997
# Epoch 53/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0253 - mean_absolute_error: 0.0992
# Epoch 54/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0251 - mean_absolute_error: 0.0988
# Epoch 55/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0250 - mean_absolute_error: 0.0985
# Epoch 56/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0250 - mean_absolute_error: 0.0992
# Epoch 57/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0249 - mean_absolute_error: 0.0990
# Epoch 58/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0246 - mean_absolute_error: 0.0979
# Epoch 59/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0244 - mean_absolute_error: 0.0976
# Epoch 60/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0243 - mean_absolute_error: 0.0976
# Epoch 61/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0242 - mean_absolute_error: 0.0973
# Epoch 62/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0240 - mean_absolute_error: 0.0968
# Epoch 63/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0239 - mean_absolute_error: 0.0967
# Epoch 64/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0237 - mean_absolute_error: 0.0965
# Epoch 65/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0236 - mean_absolute_error: 0.0963
# Epoch 66/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0235 - mean_absolute_error: 0.0960
# Epoch 67/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0234 - mean_absolute_error: 0.0957
# Epoch 68/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0233 - mean_absolute_error: 0.0956
# Epoch 69/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0232 - mean_absolute_error: 0.0955
# Epoch 70/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0232 - mean_absolute_error: 0.0953
# Epoch 71/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0230 - mean_absolute_error: 0.0949
# Epoch 72/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0229 - mean_absolute_error: 0.0948
# Epoch 73/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0227 - mean_absolute_error: 0.0945
# Epoch 74/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0227 - mean_absolute_error: 0.0945
# Epoch 75/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0226 - mean_absolute_error: 0.0942
# Epoch 76/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0224 - mean_absolute_error: 0.0940
# Epoch 77/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0224 - mean_absolute_error: 0.0938
# Epoch 78/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0223 - mean_absolute_error: 0.0933
# Epoch 79/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0222 - mean_absolute_error: 0.0938
# Epoch 80/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0220 - mean_absolute_error: 0.0931
# Epoch 81/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0219 - mean_absolute_error: 0.0929
# Epoch 82/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0219 - mean_absolute_error: 0.0927
# Epoch 83/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0218 - mean_absolute_error: 0.0922
# Epoch 84/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0217 - mean_absolute_error: 0.0925
# Epoch 85/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0216 - mean_absolute_error: 0.0920
# Epoch 86/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0214 - mean_absolute_error: 0.0915
# Epoch 87/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0214 - mean_absolute_error: 0.0918
# Epoch 88/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0214 - mean_absolute_error: 0.0917
# Epoch 89/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0214 - mean_absolute_error: 0.0913
# Epoch 90/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0211 - mean_absolute_error: 0.0909
# Epoch 91/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0211 - mean_absolute_error: 0.0911
# Epoch 92/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0211 - mean_absolute_error: 0.0905
# Epoch 93/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0212 - mean_absolute_error: 0.0915
# Epoch 94/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0211 - mean_absolute_error: 0.0916
# Epoch 95/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0207 - mean_absolute_error: 0.0898
# Epoch 96/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0206 - mean_absolute_error: 0.0895
# Epoch 97/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0207 - mean_absolute_error: 0.0898
# Epoch 98/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0204 - mean_absolute_error: 0.0892
# Epoch 99/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0204 - mean_absolute_error: 0.0889
# Epoch 100/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0203 - mean_absolute_error: 0.0887
# Epoch 1/100
# 17/17 [==============================] - 3s 6ms/step - loss: 0.8302 - mean_absolute_error: 0.9079
# Epoch 2/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.7002 - mean_absolute_error: 0.8335
# Epoch 3/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.5886 - mean_absolute_error: 0.7637
# Epoch 4/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5012 - mean_absolute_error: 0.7039
# Epoch 5/100
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4215 - mean_absolute_error: 0.6445
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3457 - mean_absolute_error: 0.5820
# Epoch 7/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.2754 - mean_absolute_error: 0.5171
# Epoch 8/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2126 - mean_absolute_error: 0.4513
# Epoch 9/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1578 - mean_absolute_error: 0.3840
# Epoch 10/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1083 - mean_absolute_error: 0.3102
# Epoch 11/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0686 - mean_absolute_error: 0.2329
# Epoch 12/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0432 - mean_absolute_error: 0.1637
# Epoch 13/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0305 - mean_absolute_error: 0.1119
# Epoch 14/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0258 - mean_absolute_error: 0.0832
# Epoch 15/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0244 - mean_absolute_error: 0.0733
# Epoch 16/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0241 - mean_absolute_error: 0.0708
# Epoch 17/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0238 - mean_absolute_error: 0.0700
# Epoch 18/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0236 - mean_absolute_error: 0.0691
# Epoch 19/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0234 - mean_absolute_error: 0.0682
# Epoch 20/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0232 - mean_absolute_error: 0.0673
# Epoch 21/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0229 - mean_absolute_error: 0.0664
# Epoch 22/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0228 - mean_absolute_error: 0.0656
# Epoch 23/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0225 - mean_absolute_error: 0.0648
# Epoch 24/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0224 - mean_absolute_error: 0.0642
# Epoch 25/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0222 - mean_absolute_error: 0.0634
# Epoch 26/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0221 - mean_absolute_error: 0.0628
# Epoch 27/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0219 - mean_absolute_error: 0.0621
# Epoch 28/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0218 - mean_absolute_error: 0.0615
# Epoch 29/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0216 - mean_absolute_error: 0.0610
# Epoch 30/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0215 - mean_absolute_error: 0.0603
# Epoch 31/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0214 - mean_absolute_error: 0.0597
# Epoch 32/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0213 - mean_absolute_error: 0.0592
# Epoch 33/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0211 - mean_absolute_error: 0.0586
# Epoch 34/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0210 - mean_absolute_error: 0.0580
# Epoch 35/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0209 - mean_absolute_error: 0.0571
# Epoch 36/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0207 - mean_absolute_error: 0.0562
# Epoch 37/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0206 - mean_absolute_error: 0.0557
# Epoch 38/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0205 - mean_absolute_error: 0.0548
# Epoch 39/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0204 - mean_absolute_error: 0.0543
# Epoch 40/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0203 - mean_absolute_error: 0.0542
# Epoch 41/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0202 - mean_absolute_error: 0.0531
# Epoch 42/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0201 - mean_absolute_error: 0.0534
# Epoch 43/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0200 - mean_absolute_error: 0.0523
# Epoch 44/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0200 - mean_absolute_error: 0.0520
# Epoch 45/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0199 - mean_absolute_error: 0.0518
# Epoch 46/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0199 - mean_absolute_error: 0.0509
# Epoch 47/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0198 - mean_absolute_error: 0.0519
# Epoch 48/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0198 - mean_absolute_error: 0.0508
# Epoch 49/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0197 - mean_absolute_error: 0.0506
# Epoch 50/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0196 - mean_absolute_error: 0.0502
# Epoch 51/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0196 - mean_absolute_error: 0.0501
# Epoch 52/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0196 - mean_absolute_error: 0.0492
# Epoch 53/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0195 - mean_absolute_error: 0.0502
# Epoch 54/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0195 - mean_absolute_error: 0.0497
# Epoch 55/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0195 - mean_absolute_error: 0.0492
# Epoch 56/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0194 - mean_absolute_error: 0.0484
# Epoch 57/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0194 - mean_absolute_error: 0.0484
# Epoch 58/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0194 - mean_absolute_error: 0.0494
# Epoch 59/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0193 - mean_absolute_error: 0.0481
# Epoch 60/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0193 - mean_absolute_error: 0.0481
# Epoch 61/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0193 - mean_absolute_error: 0.0478
# Epoch 62/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0193 - mean_absolute_error: 0.0485
# Epoch 63/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0192 - mean_absolute_error: 0.0471
# Epoch 64/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0192 - mean_absolute_error: 0.0477
# Epoch 65/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0192 - mean_absolute_error: 0.0476
# Epoch 66/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0192 - mean_absolute_error: 0.0474
# Epoch 67/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0192 - mean_absolute_error: 0.0466
# Epoch 68/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0191 - mean_absolute_error: 0.0475
# Epoch 69/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0192 - mean_absolute_error: 0.0464
# Epoch 70/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0191 - mean_absolute_error: 0.0481
# Epoch 71/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0190 - mean_absolute_error: 0.0467
# Epoch 72/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0191 - mean_absolute_error: 0.0463
# Epoch 73/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0190 - mean_absolute_error: 0.0460
# Epoch 74/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0190 - mean_absolute_error: 0.0457
# Epoch 75/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0190 - mean_absolute_error: 0.0463
# Epoch 76/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0189 - mean_absolute_error: 0.0455
# Epoch 77/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0189 - mean_absolute_error: 0.0453
# Epoch 78/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0189 - mean_absolute_error: 0.0462
# Epoch 79/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0189 - mean_absolute_error: 0.0463
# Epoch 80/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0189 - mean_absolute_error: 0.0452
# Epoch 81/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0189 - mean_absolute_error: 0.0450
# Epoch 82/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0188 - mean_absolute_error: 0.0458
# Epoch 83/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0188 - mean_absolute_error: 0.0458
# Epoch 84/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0188 - mean_absolute_error: 0.0442
# Epoch 85/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0188 - mean_absolute_error: 0.0464
# Epoch 86/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0188 - mean_absolute_error: 0.0448
# Epoch 87/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0188 - mean_absolute_error: 0.0442
# Epoch 88/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0188 - mean_absolute_error: 0.0440
# Epoch 89/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0188 - mean_absolute_error: 0.0445
# Epoch 90/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0187 - mean_absolute_error: 0.0452
# Epoch 91/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0187 - mean_absolute_error: 0.0449
# Epoch 92/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0187 - mean_absolute_error: 0.0444
# Epoch 93/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0187 - mean_absolute_error: 0.0445
# Epoch 94/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0187 - mean_absolute_error: 0.0454
# Epoch 95/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0187 - mean_absolute_error: 0.0434
# Epoch 96/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0187 - mean_absolute_error: 0.0444
# Epoch 97/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0186 - mean_absolute_error: 0.0436
# Epoch 98/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0186 - mean_absolute_error: 0.0444
# Epoch 99/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0186 - mean_absolute_error: 0.0445
# Epoch 100/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0186 - mean_absolute_error: 0.0443

# %%
def predict_train_data(scaler, model, X_train, y_train):
  train_predictions = model.predict(X_train).flatten()
  train_predictions_inv = scaler.inverse_transform(train_predictions.reshape(-1,1))

  plt.plot(train_predictions_inv)
  plt.plot(scaler.inverse_transform(y_train.reshape(-1,1)))
  # plt.plot(dates_train, train_predictions)
  # plt.plot(dates_train, y_train)
  plt.legend(['Training Predictions', 'Training Actual'])

# %%
predict_train_data(trend_scaler, model_trend, X_train_trend, y_train_trend)
predict_train_data(seasonal_scaler, model_seasonal, X_train_seasonal, y_train_seasonal)
predict_train_data(resid_scaler, model_resid, X_train_resid, y_train_resid)
# Out:
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 2s 3ms/step

# %%
def predict_test_data(scaler, model, X_test, y_test):
  test_predictions = model.predict(X_test).flatten()
  test_predictions_inv = scaler.inverse_transform(test_predictions.reshape(-1,1))
  y_test_inv = scaler.inverse_transform(y_test)

  plt.plot(test_predictions_inv)
  plt.plot(y_test_inv)
  plt.legend(['Test Predictions', 'Test Actual'])

  return test_predictions_inv

# %%
predict_trend = predict_test_data(trend_scaler, model_trend, X_test_trend, y_test_trend)
predict_seasonal = predict_test_data(seasonal_scaler, model_seasonal, X_test_seasonal, y_test_seasonal)
predict_resid = predict_test_data(resid_scaler, model_resid, X_test_resid, y_test_resid)
# Out:
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 3ms/step

# %%
data_predict_jumlah = predict_trend + predict_seasonal + predict_resid
data_predict_jumlah
# Out:
# array([[12466.7   ],
#        [12470.917 ],
#        [12470.048 ],
#        [12481.18  ],
#        [12480.418 ],
#        [12497.009 ],
#        [12510.782 ],
#        [12522.303 ],
#        [12486.32  ],
#        [12469.478 ],
#        [12463.834 ],
#        [12465.271 ],
#        [12469.064 ],
#        [12471.089 ],
#        [12466.313 ],
#        [12490.588 ],
#        [12503.233 ],
#        [12515.006 ],
#        [12514.09  ],
#        [12511.452 ],
#        [12476.612 ],
#        [12477.802 ],
#        [12477.98  ],
#        [12480.233 ],
#        [12490.267 ],
#        [12486.014 ],
#        [12477.558 ],
#        [12485.749 ],
#        [12495.823 ],
#        [12508.336 ],
#        [12505.665 ],
#        [12476.635 ],
#        [12431.917 ],
#        [12451.191 ],
#        [12478.471 ],
#        [12481.162 ],
#        [12508.021 ],
#        [12528.957 ],
#        [12541.485 ],
#        [12565.266 ],
#        [12596.995 ],
#        [12603.215 ],
#        [12599.599 ],
#        [12597.079 ],
#        [12567.722 ],
#        [12590.693 ],
#        [12630.665 ],
#        [12629.816 ],
#        [12646.848 ],
#        [12705.395 ],
#        [12767.859 ],
#        [12809.418 ],
#        [12825.962 ],
#        [12925.002 ],
#        [12969.522 ],
#        [12979.443 ],
#        [12961.325 ],
#        [13000.907 ],
#        [13052.846 ],
#        [13078.722 ],
#        [13081.751 ],
#        [13100.074 ],
#        [13105.235 ],
#        [13107.449 ],
#        [13124.307 ],
#        [13126.902 ],
#        [13109.687 ],
#        [13051.81  ],
#        [13020.992 ],
#        [13037.89  ],
#        [13075.    ],
#        [13074.345 ],
#        [13057.581 ],
#        [13062.521 ],
#        [13065.139 ],
#        [13063.357 ],
#        [13073.08  ],
#        [13090.056 ],
#        [13095.856 ],
#        [13053.675 ],
#        [13039.875 ],
#        [13060.403 ],
#        [13090.789 ],
#        [13097.151 ],
#        [13091.755 ],
#        [13093.814 ],
#        [13092.583 ],
#        [13090.647 ],
#        [13089.263 ],
#        [13086.735 ],
#        [13085.569 ],
#        [13078.736 ],
#        [13087.564 ],
#        [13081.358 ],
#        [13081.764 ],
#        [13087.226 ],
#        [13083.058 ],
#        [13087.462 ],
#        [13091.258 ],
#        [13095.733 ],
#        [13088.679 ],
#        [13085.958 ],
#        [13089.533 ],
#        [13080.225 ],
#        [13092.01  ],
#        [13094.645 ],
#        [13096.517 ],
#        [13085.611 ],
#        [13076.646 ],
#        [13065.931 ],
#        [13062.532 ],
#        [13060.495 ],
#        [13078.458 ],
#        [13071.482 ],
#        [13084.885 ],
#        [13086.674 ],
#        [13086.956 ],
#        [13088.645 ],
#        [13088.248 ],
#        [13091.597 ],
#        [13095.943 ],
#        [13103.231 ],
#        [13091.8125],
#        [13099.996 ],
#        [13117.935 ],
#        [13115.147 ],
#        [13115.388 ],
#        [13112.146 ],
#        [13106.804 ],
#        [13108.303 ],
#        [13107.678 ],
#        [13107.899 ],
#        [13114.103 ],
#        [13118.976 ],
#        [13102.662 ]], dtype=float32)

# %%
# df_beras['Harga Beras'][q_80:]
y_test_trend_scaler_inverse = trend_scaler.inverse_transform(y_test_trend)
y_test_seasonal_scaler_inverse = seasonal_scaler.inverse_transform(y_test_seasonal)
y_test_resid_scaler_inverse = resid_scaler.inverse_transform(y_test_resid)
y_test_asli = y_test_trend_scaler_inverse + y_test_seasonal_scaler_inverse + y_test_resid_scaler_inverse
y_test_asli
# Out:
# array([[12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12400.],
#        [12450.],
#        [12450.],
#        [12450.],
#        [12500.],
#        [12500.],
#        [12550.],
#        [12550.],
#        [12550.],
#        [12550.],
#        [12600.],
#        [12750.],
#        [12750.],
#        [12750.],
#        [12800.],
#        [12800.],
#        [12850.],
#        [12950.],
#        [13050.],
#        [13050.],
#        [13050.],
#        [13400.],
#        [13600.],
#        [13650.],
#        [13700.],
#        [13750.],
#        [13750.],
#        [13800.],
#        [13800.],
#        [13800.],
#        [13800.],
#        [13850.],
#        [13850.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13950.],
#        [13900.],
#        [13900.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13900.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [13950.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.],
#        [14000.]])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from math import sqrt

rmse = sqrt(mean_squared_error(data_predict_jumlah,y_test_asli))
mae = mean_absolute_error(data_predict_jumlah,y_test_asli)
print("Root Mean Square Error:", rmse)
print("Mean Absolute Error:", mae)

# R Square
r = r2_score(data_predict_jumlah,y_test_asli)

# Mean Magnitude of Relative Error
mmre = (abs((data_predict_jumlah - y_test_asli) / y_test_asli)).mean()

# Median Magnitude of Relative Error
mdmre = np.median(abs((data_predict_jumlah - y_test_asli) / y_test_asli))

# Mean Magnitude of Error Relative
mmer = (abs(data_predict_jumlah - y_test_asli)).mean()

# Mean Square Error
mse = mean_squared_error(data_predict_jumlah, y_test_asli)

# Menampilkan hasil
print("R Square: {:.4f}".format(r))
print("Mean Magnitude of Relative Error: {:.4f}".format(mmre))
print("Median Magnitude of Relative Error: {:.4f}".format(mdmre))
print("Mean Magnitude of Error Relative: ", mmer)
print("Mean Square Error:", mse)
# Out:
# Root Mean Square Error: 662.8928505246658
# Mean Absolute Error: 548.8991319444445
# R Square: -4.8153
# Mean Magnitude of Relative Error: 0.0397
# Median Magnitude of Relative Error: 0.0578
# Mean Magnitude of Error Relative:  548.8991319444445
# Mean Square Error: 439426.93127671705

# %% [markdown]
# <a href="https://colab.research.google.com/github/Danazzz/dataset-beras-scm/blob/main/SCM_Beras1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import zipfile, os
import numpy as np
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
from statsmodels.tsa.stattools import adfuller
plt.rcParams['figure.figsize'] = 15, 6            #agar semua plot ukurannya sama
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.vector_ar.var_model import VAR

import xgboost

# %%
#Load data BI
converters = {
    'Beras': lambda x: str(x.replace(',', '')),
    'Beras Kualitas Bawah I' : lambda x: str(x.replace(',', '')),
    'Beras Kualitas Medium I' : lambda x: str(x.replace(',', '')),
    'Beras Kualitas Super I' : lambda x: str(x.replace(',', '')),
}

df1 = pd.read_csv('./csv/Tabel Harga Berdasarkan Daerah Jabar.csv', converters=converters)
df1
# Out:
#          Komoditas  Beras Beras Kualitas Bawah I Beras Kualitas Bawah II  \
# 0     01/ 01/ 2020      -                      -                       -
# 1     02/ 01/ 2020  11150                  10100                    9500
# 2     03/ 01/ 2020  11150                  10100                    9500
# 3     06/ 01/ 2020  11150                  10150                    9550
# 4     07/ 01/ 2020  11200                  10200                    9650
# ...            ...    ...                    ...                     ...
# 1093  11/ 03/ 2024  15800                  14950                   14500
# 1094  12/ 03/ 2024  15800                  14950                   14500
# 1095  13/ 03/ 2024  15750                  14900                   14400
# 1096  14/ 03/ 2024  15750                  14900                   14400
# 1097  15/ 03/ 2024  15750                  14950                   14400
#
#      Beras Kualitas Medium I Beras Kualitas Medium II Beras Kualitas Super I  \
# 0                          -                        -                      -
# 1                      11350                    10850                  12900
# 2                      11350                    10850                  12900
# 3                      11350                    10850                  12900
# 4                      11400                    10900                  12950
# ...                      ...                      ...                    ...
# 1093                   16050                    15550                  17250
# 1094                   16050                    15550                  17250
# 1095                   16000                    15450                  17200
# 1096                   16000                    15450                  17200
# 1097                   16000                    15500                  17200
#
#      Beras Kualitas Super II Beras Kualitas Bawah Beras Kualitas Medium  \
# 0                          -                    0                     0
# 1                      12100                 9800                 11100
# 2                      12100                 9800                 11100
# 3                      12100                 9850                 11100
# 4                      12150                 9925                 11150
# ...                      ...                  ...                   ...
# 1093                   16550                14725                 15800
# 1094                   16550                14725                 15800
# 1095                   16550                14650                 15725
# 1096                   16550                14650                 15725
# 1097                   16550                14675                 15750
#
#      Beras Kualitas Super
# 0                       0
# 1                   12500
# 2                   12500
# 3                   12500
# 4                   12550
# ...                   ...
# 1093                16900
# 1094                16900
# 1095                16875
# 1096                16875
# 1097                16875
#
# [1098 rows x 11 columns]

# %%
print('Data Types:')
print(df1.dtypes)
# Out:
# Data Types:
# Komoditas                   object
# Beras                       object
# Beras Kualitas Bawah I      object
# Beras Kualitas Bawah II     object
# Beras Kualitas Medium I     object
# Beras Kualitas Medium II    object
# Beras Kualitas Super I      object
# Beras Kualitas Super II     object
# Beras Kualitas Bawah        object
# Beras Kualitas Medium       object
# Beras Kualitas Super        object
# dtype: object

# %%
#Mengubah tanggal menjadi index
con=df1['Komoditas']
df1['Komoditas'] = pd.to_datetime(df1['Komoditas'], format='%d/ %m/ %Y')
df1.set_index('Komoditas', inplace=True)
#check datatype of index
df1.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14',
#                ...
#                '2024-03-04', '2024-03-05', '2024-03-06', '2024-03-07',
#                '2024-03-08', '2024-03-11', '2024-03-12', '2024-03-13',
#                '2024-03-14', '2024-03-15'],
#               dtype='datetime64[ns]', name='Komoditas', length=1098, freq=None)

# %%
df1 = df1.iloc[:, [0, 7, 8, 9]]
df1
# Out:
#             Beras Beras Kualitas Bawah Beras Kualitas Medium  \
# Komoditas
# 2020-01-01      -                    0                     0
# 2020-01-02  11150                 9800                 11100
# 2020-01-03  11150                 9800                 11100
# 2020-01-06  11150                 9850                 11100
# 2020-01-07  11200                 9925                 11150
# ...           ...                  ...                   ...
# 2024-03-11  15800                14725                 15800
# 2024-03-12  15800                14725                 15800
# 2024-03-13  15750                14650                 15725
# 2024-03-14  15750                14650                 15725
# 2024-03-15  15750                14675                 15750
#
#            Beras Kualitas Super
# Komoditas
# 2020-01-01                    0
# 2020-01-02                12500
# 2020-01-03                12500
# 2020-01-06                12500
# 2020-01-07                12550
# ...                         ...
# 2024-03-11                16900
# 2024-03-12                16900
# 2024-03-13                16875
# 2024-03-14                16875
# 2024-03-15                16875
#
# [1098 rows x 4 columns]

# %%
# Mengubah - menjadi 0
df1.replace('-', np.nan, inplace=True)
df1.replace('#DIV/0!', np.nan, inplace=True)
df1
# Out:
# /var/folders/3s/37cdhq1x7fdcds5p4y_vnbp00000gn/T/ipykernel_33547/1513190452.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('-', np.nan, inplace=True)
# /var/folders/3s/37cdhq1x7fdcds5p4y_vnbp00000gn/T/ipykernel_33547/1513190452.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('#DIV/0!', np.nan, inplace=True)
#             Beras Beras Kualitas Bawah Beras Kualitas Medium  \
# Komoditas
# 2020-01-01    NaN                    0                     0
# 2020-01-02  11150                 9800                 11100
# 2020-01-03  11150                 9800                 11100
# 2020-01-06  11150                 9850                 11100
# 2020-01-07  11200                 9925                 11150
# ...           ...                  ...                   ...
# 2024-03-11  15800                14725                 15800
# 2024-03-12  15800                14725                 15800
# 2024-03-13  15750                14650                 15725
# 2024-03-14  15750                14650                 15725
# 2024-03-15  15750                14675                 15750
#
#            Beras Kualitas Super
# Komoditas
# 2020-01-01                    0
# 2020-01-02                12500
# 2020-01-03                12500
# 2020-01-06                12500
# 2020-01-07                12550
# ...                         ...
# 2024-03-11                16900
# 2024-03-12                16900
# 2024-03-13                16875
# 2024-03-14                16875
# 2024-03-15                16875
#
# [1098 rows x 4 columns]

# %%
df1 = df1.astype('Int64')
df1
# Out:
#             Beras  Beras Kualitas Bawah  Beras Kualitas Medium  \
# Komoditas
# 2020-01-01   <NA>                     0                      0
# 2020-01-02  11150                  9800                  11100
# 2020-01-03  11150                  9800                  11100
# 2020-01-06  11150                  9850                  11100
# 2020-01-07  11200                  9925                  11150
# ...           ...                   ...                    ...
# 2024-03-11  15800                 14725                  15800
# 2024-03-12  15800                 14725                  15800
# 2024-03-13  15750                 14650                  15725
# 2024-03-14  15750                 14650                  15725
# 2024-03-15  15750                 14675                  15750
#
#             Beras Kualitas Super
# Komoditas
# 2020-01-01                     0
# 2020-01-02                 12500
# 2020-01-03                 12500
# 2020-01-06                 12500
# 2020-01-07                 12550
# ...                          ...
# 2024-03-11                 16900
# 2024-03-12                 16900
# 2024-03-13                 16875
# 2024-03-14                 16875
# 2024-03-15                 16875
#
# [1098 rows x 4 columns]

# %%
df1.info()
df1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1098 entries, 2020-01-01 to 2024-03-15
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Beras                  1050 non-null   Int64
#  1   Beras Kualitas Bawah   1051 non-null   Int64
#  2   Beras Kualitas Medium  1051 non-null   Int64
#  3   Beras Kualitas Super   1051 non-null   Int64
# dtypes: Int64(4)
# memory usage: 47.2 KB
# (1098, 4)

# %%
converters = {
    'Luas Panen Padi': lambda x: str(x.replace('.', '')),
    'GKP Tingkat Petani': lambda x: str(x.replace('.', '')),
    'GKP Tingkat Penggilingan' : lambda x: str(x.replace('.', '')),
    'GKG Tingkat Penggilingan' : lambda x: str(x.replace('.', '')),
    'Beras Medium Penggilingan' : lambda x: str(x.replace('.', '')),
    'Beras Premium Penggilingan' : lambda x: str(x.replace('.', '')),
}

#Load data
df2 = pd.read_csv('./csv/export-produsen-2.csv', converters=converters)
# print(df2.head())
df2
# Out:
#        Komoditas Luas Panen Padi GKP Tingkat Petani GKP Tingkat Penggilingan  \
# 0     01/01/2020              20               3700                     4000
# 1     02/01/2020               -                  -                        -
# 2     03/01/2020               -                  -                        -
# 3     04/01/2020               -                  -                        -
# 4     05/01/2020               -                  -                        -
# ...          ...             ...                ...                      ...
# 1531  11/03/2024              10               6760                     7140
# 1532  12/03/2024              10               6530                     6930
# 1533  13/03/2024              10               6480                     6920
# 1534  14/03/2024              10               6510                     7060
# 1535  15/03/2024              10               6480                     6930
#
#      GKG Tingkat Penggilingan Beras Medium Penggilingan  \
# 0                        4500                      8200
# 1                           -                         -
# 2                           -                         -
# 3                           -                         -
# 4                           -                         -
# ...                       ...                       ...
# 1531                     8330                     14180
# 1532                     8260                     14140
# 1533                     8240                     14040
# 1534                     8240                     14050
# 1535                     8190                     14120
#
#      Beras Premium Penggilingan Ratarata Beras Penggilingan  \
# 0                          9200                        8700
# 1                             -                     #DIV/0!
# 2                             -                     #DIV/0!
# 3                             -                     #DIV/0!
# 4                             -                     #DIV/0!
# ...                         ...                         ...
# 1531                      15640                       14910
# 1532                      15480                       14810
# 1533                      15460                       14750
# 1534                      15510                       14780
# 1535                      15470                       14795
#
#      Jagung Pipilan Kering Kedelai Biji Kering (Lokal) Bawang Merah  \
# 0                        -                           -            -
# 1                        -                           -            -
# 2                        -                           -            -
# 3                        -                           -            -
# 4                        -                           -            -
# ...                    ...                         ...          ...
# 1531                  5540                       10610        15990
# 1532                  5250                       10610        16330
# 1533                  5280                       10310        15990
# 1534                  5280                       10310        15840
# 1535                  5460                       10310        15370
#
#      Cabai Merah Keriting Cabai Rawit Merah Sapi (Hidup)  \
# 0                       -                 -            -
# 1                       -                 -            -
# 2                       -                 -            -
# 3                       -                 -            -
# 4                       -                 -            -
# ...                   ...               ...          ...
# 1531                41880             45050        54440
# 1532                42830             43390        54470
# 1533                43770             42270        54560
# 1534                45070             41840        54550
# 1535                44550             42570        54480
#
#      Ayam Ras Pedaging (Hidup) Telur Ayam Ras Stok GKG Tingkat Penggilingan  \
# 0                            -              -                           600
# 1                            -              -                             -
# 2                            -              -                             -
# 3                            -              -                             -
# 4                            -              -                             -
# ...                        ...            ...                           ...
# 1531                     24480          27540                           120
# 1532                     24480          28260                           120
# 1533                     24000          28200                           100
# 1534                     24010          28130                           150
# 1535                     23810          28100                           150
#
#      Stok Beras Tingkat Penggilingan
# 0                                150
# 1                                  -
# 2                                  -
# 3                                  -
# 4                                  -
# ...                              ...
# 1531                              80
# 1532                              80
# 1533                              60
# 1534                              70
# 1535                              80
#
# [1536 rows x 18 columns]

# %% [markdown]
# PRODUSEN
# Panel Harga Pangan pada tingkat produsen yang diamati meliputi:
# - Luas Lahan/Sawah Padi, persentase (%) luas panen Padi di kecamatan sentra produksi.
# - GKP Tingkat Petani, harga di Petani (Rp/Kg)
# - GKP Tingkat Penggilingan, harga di Penggilingan (Rp/Kg)
# - GKG Tingkat Penggilingan, harga di Penggilingan (Rp/Kg)
# - Beras Medium Tingkat Penggilingan, harga di Penggilingan (Rp/Kg)
# - Beras Premium Tingkat Penggilingan, harga di Penggilingan (Rp/Kg)
# - Stok GKG Tingkat Penggilingan, stok dalam satuan Kwintal
# - Stok Beras Tingkat Penggilingan, stok dalam satuan Kwintal

# %%
print('Data Types:')
print(df2.dtypes)
# Out:
# Data Types:
# Komoditas                          object
# Luas Panen Padi                    object
# GKP Tingkat Petani                 object
# GKP Tingkat Penggilingan           object
# GKG Tingkat Penggilingan           object
# Beras Medium Penggilingan          object
# Beras Premium Penggilingan         object
# Ratarata Beras Penggilingan        object
# Jagung Pipilan Kering              object
# Kedelai Biji Kering (Lokal)        object
# Bawang Merah                       object
# Cabai Merah Keriting               object
# Cabai Rawit Merah                  object
# Sapi (Hidup)                       object
# Ayam Ras Pedaging (Hidup)          object
# Telur Ayam Ras                     object
# Stok GKG Tingkat Penggilingan      object
# Stok Beras Tingkat Penggilingan    object
# dtype: object

# %%
#Mengubah tanggal menjadi index
con=df2['Komoditas']
df2['Komoditas'] = pd.to_datetime(df2['Komoditas'], format='%d/%m/%Y')
df2.set_index('Komoditas', inplace=True)
#check datatype of index
df2.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-09',
#                '2024-03-10', '2024-03-11', '2024-03-12', '2024-03-13',
#                '2024-03-14', '2024-03-15'],
#               dtype='datetime64[ns]', name='Komoditas', length=1536, freq=None)

# %%
print(df2.columns)
# Out:
# Index(['Luas Panen Padi', 'GKP Tingkat Petani', 'GKP Tingkat Penggilingan',
#        'GKG Tingkat Penggilingan', 'Beras Medium Penggilingan',
#        'Beras Premium Penggilingan', 'Ratarata Beras Penggilingan',
#        'Jagung Pipilan Kering', 'Kedelai Biji Kering (Lokal)', 'Bawang Merah',
#        'Cabai Merah Keriting', 'Cabai Rawit Merah', 'Sapi (Hidup)',
#        'Ayam Ras Pedaging (Hidup)', 'Telur Ayam Ras',
#        'Stok GKG Tingkat Penggilingan', 'Stok Beras Tingkat Penggilingan'],
#       dtype='object')

# %%
df2 = df2.iloc[:, [0, 1, 2, 3, 6, 15, 16]]
df2
# Out:
#            Luas Panen Padi GKP Tingkat Petani GKP Tingkat Penggilingan  \
# Komoditas
# 2020-01-01              20               3700                     4000
# 2020-01-02               -                  -                        -
# 2020-01-03               -                  -                        -
# 2020-01-04               -                  -                        -
# 2020-01-05               -                  -                        -
# ...                    ...                ...                      ...
# 2024-03-11              10               6760                     7140
# 2024-03-12              10               6530                     6930
# 2024-03-13              10               6480                     6920
# 2024-03-14              10               6510                     7060
# 2024-03-15              10               6480                     6930
#
#            GKG Tingkat Penggilingan Ratarata Beras Penggilingan  \
# Komoditas
# 2020-01-01                     4500                        8700
# 2020-01-02                        -                     #DIV/0!
# 2020-01-03                        -                     #DIV/0!
# 2020-01-04                        -                     #DIV/0!
# 2020-01-05                        -                     #DIV/0!
# ...                             ...                         ...
# 2024-03-11                     8330                       14910
# 2024-03-12                     8260                       14810
# 2024-03-13                     8240                       14750
# 2024-03-14                     8240                       14780
# 2024-03-15                     8190                       14795
#
#            Stok GKG Tingkat Penggilingan Stok Beras Tingkat Penggilingan
# Komoditas
# 2020-01-01                           600                             150
# 2020-01-02                             -                               -
# 2020-01-03                             -                               -
# 2020-01-04                             -                               -
# 2020-01-05                             -                               -
# ...                                  ...                             ...
# 2024-03-11                           120                              80
# 2024-03-12                           120                              80
# 2024-03-13                           100                              60
# 2024-03-14                           150                              70
# 2024-03-15                           150                              80
#
# [1536 rows x 7 columns]

# %%
# Mengubah - menjadi 0
df2.replace('-', np.nan, inplace=True)
df2.replace('#DIV/0!', np.nan, inplace=True)
df2
# Out:
# /var/folders/3s/37cdhq1x7fdcds5p4y_vnbp00000gn/T/ipykernel_33547/1801948625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace('-', np.nan, inplace=True)
# /var/folders/3s/37cdhq1x7fdcds5p4y_vnbp00000gn/T/ipykernel_33547/1801948625.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.replace('#DIV/0!', np.nan, inplace=True)
#            Luas Panen Padi GKP Tingkat Petani GKP Tingkat Penggilingan  \
# Komoditas
# 2020-01-01              20               3700                     4000
# 2020-01-02             NaN                NaN                      NaN
# 2020-01-03             NaN                NaN                      NaN
# 2020-01-04             NaN                NaN                      NaN
# 2020-01-05             NaN                NaN                      NaN
# ...                    ...                ...                      ...
# 2024-03-11              10               6760                     7140
# 2024-03-12              10               6530                     6930
# 2024-03-13              10               6480                     6920
# 2024-03-14              10               6510                     7060
# 2024-03-15              10               6480                     6930
#
#            GKG Tingkat Penggilingan Ratarata Beras Penggilingan  \
# Komoditas
# 2020-01-01                     4500                        8700
# 2020-01-02                      NaN                         NaN
# 2020-01-03                      NaN                         NaN
# 2020-01-04                      NaN                         NaN
# 2020-01-05                      NaN                         NaN
# ...                             ...                         ...
# 2024-03-11                     8330                       14910
# 2024-03-12                     8260                       14810
# 2024-03-13                     8240                       14750
# 2024-03-14                     8240                       14780
# 2024-03-15                     8190                       14795
#
#            Stok GKG Tingkat Penggilingan Stok Beras Tingkat Penggilingan
# Komoditas
# 2020-01-01                           600                             150
# 2020-01-02                           NaN                             NaN
# 2020-01-03                           NaN                             NaN
# 2020-01-04                           NaN                             NaN
# 2020-01-05                           NaN                             NaN
# ...                                  ...                             ...
# 2024-03-11                           120                              80
# 2024-03-12                           120                              80
# 2024-03-13                           100                              60
# 2024-03-14                           150                              70
# 2024-03-15                           150                              80
#
# [1536 rows x 7 columns]

# %%
# ini datanya ada yang gajelas 1
# luas panen 20710?
df2 = df2.drop(df2[df2['Luas Panen Padi'] == '20710'].index)

# %%
df2 = df2.astype('Int64')
df2
# Out:
#             Luas Panen Padi  GKP Tingkat Petani  GKP Tingkat Penggilingan  \
# Komoditas
# 2020-01-01               20                3700                      4000
# 2020-01-02             <NA>                <NA>                      <NA>
# 2020-01-03             <NA>                <NA>                      <NA>
# 2020-01-04             <NA>                <NA>                      <NA>
# 2020-01-05             <NA>                <NA>                      <NA>
# ...                     ...                 ...                       ...
# 2024-03-11               10                6760                      7140
# 2024-03-12               10                6530                      6930
# 2024-03-13               10                6480                      6920
# 2024-03-14               10                6510                      7060
# 2024-03-15               10                6480                      6930
#
#             GKG Tingkat Penggilingan  Ratarata Beras Penggilingan  \
# Komoditas
# 2020-01-01                      4500                         8700
# 2020-01-02                      <NA>                         <NA>
# 2020-01-03                      <NA>                         <NA>
# 2020-01-04                      <NA>                         <NA>
# 2020-01-05                      <NA>                         <NA>
# ...                              ...                          ...
# 2024-03-11                      8330                        14910
# 2024-03-12                      8260                        14810
# 2024-03-13                      8240                        14750
# 2024-03-14                      8240                        14780
# 2024-03-15                      8190                        14795
#
#             Stok GKG Tingkat Penggilingan  Stok Beras Tingkat Penggilingan
# Komoditas
# 2020-01-01                            600                              150
# 2020-01-02                           <NA>                             <NA>
# 2020-01-03                           <NA>                             <NA>
# 2020-01-04                           <NA>                             <NA>
# 2020-01-05                           <NA>                             <NA>
# ...                                   ...                              ...
# 2024-03-11                            120                               80
# 2024-03-12                            120                               80
# 2024-03-13                            100                               60
# 2024-03-14                            150                               70
# 2024-03-15                            150                               80
#
# [1535 rows x 7 columns]

# %%
df2.info()
df2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1535 entries, 2020-01-01 to 2024-03-15
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Luas Panen Padi                  1072 non-null   Int64
#  1   GKP Tingkat Petani               1073 non-null   Int64
#  2   GKP Tingkat Penggilingan         1073 non-null   Int64
#  3   GKG Tingkat Penggilingan         1075 non-null   Int64
#  4   Ratarata Beras Penggilingan      1075 non-null   Int64
#  5   Stok GKG Tingkat Penggilingan    1063 non-null   Int64
#  6   Stok Beras Tingkat Penggilingan  1063 non-null   Int64
# dtypes: Int64(7)
# memory usage: 106.4 KB
# (1535, 7)

# %%
df3 = pd.merge(df2, df1, on='Komoditas', how='left')
df3
# Out:
#             Luas Panen Padi  GKP Tingkat Petani  GKP Tingkat Penggilingan  \
# Komoditas
# 2020-01-01               20                3700                      4000
# 2020-01-02             <NA>                <NA>                      <NA>
# 2020-01-03             <NA>                <NA>                      <NA>
# 2020-01-04             <NA>                <NA>                      <NA>
# 2020-01-05             <NA>                <NA>                      <NA>
# ...                     ...                 ...                       ...
# 2024-03-11               10                6760                      7140
# 2024-03-12               10                6530                      6930
# 2024-03-13               10                6480                      6920
# 2024-03-14               10                6510                      7060
# 2024-03-15               10                6480                      6930
#
#             GKG Tingkat Penggilingan  Ratarata Beras Penggilingan  \
# Komoditas
# 2020-01-01                      4500                         8700
# 2020-01-02                      <NA>                         <NA>
# 2020-01-03                      <NA>                         <NA>
# 2020-01-04                      <NA>                         <NA>
# 2020-01-05                      <NA>                         <NA>
# ...                              ...                          ...
# 2024-03-11                      8330                        14910
# 2024-03-12                      8260                        14810
# 2024-03-13                      8240                        14750
# 2024-03-14                      8240                        14780
# 2024-03-15                      8190                        14795
#
#             Stok GKG Tingkat Penggilingan  Stok Beras Tingkat Penggilingan  \
# Komoditas
# 2020-01-01                            600                              150
# 2020-01-02                           <NA>                             <NA>
# 2020-01-03                           <NA>                             <NA>
# 2020-01-04                           <NA>                             <NA>
# 2020-01-05                           <NA>                             <NA>
# ...                                   ...                              ...
# 2024-03-11                            120                               80
# 2024-03-12                            120                               80
# 2024-03-13                            100                               60
# 2024-03-14                            150                               70
# 2024-03-15                            150                               80
#
#             Beras  Beras Kualitas Bawah  Beras Kualitas Medium  \
# Komoditas
# 2020-01-01   <NA>                     0                      0
# 2020-01-02  11150                  9800                  11100
# 2020-01-03  11150                  9800                  11100
# 2020-01-04   <NA>                  <NA>                   <NA>
# 2020-01-05   <NA>                  <NA>                   <NA>
# ...           ...                   ...                    ...
# 2024-03-11  15800                 14725                  15800
# 2024-03-12  15800                 14725                  15800
# 2024-03-13  15750                 14650                  15725
# 2024-03-14  15750                 14650                  15725
# 2024-03-15  15750                 14675                  15750
#
#             Beras Kualitas Super
# Komoditas
# 2020-01-01                     0
# 2020-01-02                 12500
# 2020-01-03                 12500
# 2020-01-04                  <NA>
# 2020-01-05                  <NA>
# ...                          ...
# 2024-03-11                 16900
# 2024-03-12                 16900
# 2024-03-13                 16875
# 2024-03-14                 16875
# 2024-03-15                 16875
#
# [1535 rows x 11 columns]

# %%
df3.info()
df3.nunique()

# Menampilkan nilai unik dalam setiap kolom
for col in df3.columns:
    unique_values = df3[col].unique()
    print(f"Nilai unik dalam kolom {col}: {unique_values}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1535 entries, 2020-01-01 to 2024-03-15
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Luas Panen Padi                  1072 non-null   Int64
#  1   GKP Tingkat Petani               1073 non-null   Int64
#  2   GKP Tingkat Penggilingan         1073 non-null   Int64
#  3   GKG Tingkat Penggilingan         1075 non-null   Int64
#  4   Ratarata Beras Penggilingan      1075 non-null   Int64
#  5   Stok GKG Tingkat Penggilingan    1063 non-null   Int64
#  6   Stok Beras Tingkat Penggilingan  1063 non-null   Int64
#  7   Beras                            1049 non-null   Int64
#  8   Beras Kualitas Bawah             1050 non-null   Int64
#  9   Beras Kualitas Medium            1050 non-null   Int64
#  10  Beras Kualitas Super             1050 non-null   Int64
# dtypes: Int64(11)
# memory usage: 160.4 KB
# Nilai unik dalam kolom Luas Panen Padi: <IntegerArray>
# [20, <NA>, 0, 10, 40, 50, 70, 60, 80, 90, 30, 100]
# Length: 12, dtype: Int64
# Nilai unik dalam kolom GKP Tingkat Petani: <IntegerArray>
# [3700, <NA>, 4500, 4400, 4240, 4150, 4000, 3850, 4160, 4120,
#  ...
#  7320, 7140, 7310, 7130, 7200, 7150, 7290, 7030, 6930, 6480]
# Length: 233, dtype: Int64
# Nilai unik dalam kolom GKP Tingkat Penggilingan: <IntegerArray>
# [4000, <NA>, 4700, 4800, 4650, 4450, 4500, 4150, 4100, 4230,
#  ...
#  7600, 7640, 7590, 7610, 7700, 7530, 7510, 7560, 7430, 7140]
# Length: 262, dtype: Int64
# Nilai unik dalam kolom GKG Tingkat Penggilingan: <IntegerArray>
# [4500, <NA>, 5800, 5200, 5600, 5240, 5110, 5230, 5250, 5150,
#  ...
#  9020, 9010, 8980, 8960, 8820, 8500, 8490, 8540, 8550, 8260]
# Length: 293, dtype: Int64
# Nilai unik dalam kolom Ratarata Beras Penggilingan: <IntegerArray>
# [ 8700,  <NA>,  9200,  9445,  9395,  9470,  9250,  9560,  9500,  9515,
#  ...
#  15150, 14960, 14985, 14940, 14955, 14910, 14810, 14750, 14780, 14795]
# Length: 399, dtype: Int64
# Nilai unik dalam kolom Stok GKG Tingkat Penggilingan: <IntegerArray>
# [ 600, <NA>,   20,   70,   30,   40,   60,   90,   50,   80,  150,  100,  110,
#   120,  130,  180,  170,  160,  140,  210,  240,  200,  420,  520,  480,  220,
#   290,  280,  400,  350,  320,  250,  300,  270,  260,  310,  340,  360,  230,
#   500,  190]
# Length: 41, dtype: Int64
# Nilai unik dalam kolom Stok Beras Tingkat Penggilingan: <IntegerArray>
# [ 150, <NA>,   10,   20,   40,   50,   30,   60,   70,   80,   90,  100,  110,
#   170,  200,  130,  190,  220,  250,  160,  140,  260,  270,  240]
# Length: 24, dtype: Int64
# Nilai unik dalam kolom Beras: <IntegerArray>
# [ <NA>, 11150, 11200, 11250, 11300, 11350, 11400, 11450, 11500, 11000, 11100,
#  11750, 11850, 11950, 11550, 11600, 11650, 11700, 11800, 11900, 12050, 12100,
#  12150, 12300, 12350, 12400, 12450, 12500, 12600, 12550, 12750, 12800, 12850,
#  12950, 13050, 13400, 13600, 13650, 13700, 13750, 13800, 13850, 13900, 13950,
#  14000, 14050, 14100, 14150, 14250, 14300, 14450, 14500, 14550, 14650, 14750,
#  14800, 15150, 15250, 15300, 15450, 15500, 15850, 15550, 15600, 15650, 15700,
#  15750, 15800]
# Length: 68, dtype: Int64
# Nilai unik dalam kolom Beras Kualitas Bawah: <IntegerArray>
# [    0,  9800,  <NA>,  9850,  9925,  9950,  9975, 10075, 10100,  4952,
#  ...
#  14450, 14475, 14575, 14600, 14675, 14825, 14775, 14750, 14725, 14650]
# Length: 103, dtype: Int64
# Nilai unik dalam kolom Beras Kualitas Medium: <IntegerArray>
# [    0, 11100,  <NA>, 11150, 11175, 11200, 11225, 11325, 11350, 11400, 11425,
#  11450, 11300, 11275, 11250, 11075, 11025, 11125, 11050, 10950, 11375, 11475,
#  11500, 11600, 11625, 11650, 11675, 11700, 11725, 11800, 11850, 11925, 11950,
#  11975, 12050, 12250, 12350, 12400, 12375, 12500, 12325, 12300, 12275, 12425,
#  12450, 12650, 12675, 12725, 12750, 12900, 12950, 12975, 13325, 13550, 13600,
#  13650, 13675, 13725, 13750, 13775, 13800, 13825, 13875, 13900, 13925, 13975,
#  14000, 14050, 14225, 14275, 14400, 14450, 14575, 14650, 14750, 15100, 15200,
#  15425, 15475, 15875, 15500, 15550, 15650, 15700, 15750, 15800, 15850, 15725]
# Length: 88, dtype: Int64
# Nilai unik dalam kolom Beras Kualitas Super: <IntegerArray>
# [    0, 12500,  <NA>, 12550, 12575, 12625, 12675, 12700, 12725, 12750, 12775,
#  12800, 12825, 12650, 12175, 12475, 12600, 14200, 14300, 12900, 14550, 12850,
#  12875, 12925, 12950, 12975, 13000, 13025, 13050, 13075, 13100, 13125, 13150,
#  13175, 13200, 13250, 13275, 13350, 13425, 13625, 13650, 13700, 13750, 13775,
#  13875, 14025, 13825, 14125, 13675, 13725, 13900, 13950, 13975, 14000, 14100,
#  14525, 14750, 14800, 14825, 14875, 14900, 14950, 15000, 15050, 15025, 15100,
#  15125, 15150, 15200, 15275, 15350, 15400, 15525, 15675, 15700, 15800, 15850,
#  15900, 16275, 16325, 16375, 16475, 16625, 16675, 16550, 16725, 16800, 16850,
#  16900, 16925, 16950, 16875]
# Length: 92, dtype: Int64

# %%
# plt.plot(df3)
df3[['Beras']].plot(style='.-', use_index=True)
# df3[['GKP Tingkat Petani']].loc['2020-01-01':'2024-03-01'].plot(style='.-')
plt.tight_layout()
plt.show()

# %%
# Clean dataset df3 from NaN
df3 = df3.dropna()
df3
# Out:
#             Luas Panen Padi  GKP Tingkat Petani  GKP Tingkat Penggilingan  \
# Komoditas
# 2021-03-15               10                4000                      4150
# 2021-03-16               10                3850                      4100
# 2021-03-17               10                4160                      4230
# 2021-03-18               10                4120                      4190
# 2021-03-19               10                4190                      4290
# ...                     ...                 ...                       ...
# 2024-03-11               10                6760                      7140
# 2024-03-12               10                6530                      6930
# 2024-03-13               10                6480                      6920
# 2024-03-14               10                6510                      7060
# 2024-03-15               10                6480                      6930
#
#             GKG Tingkat Penggilingan  Ratarata Beras Penggilingan  \
# Komoditas
# 2021-03-15                      5050                         9465
# 2021-03-16                      4740                         9360
# 2021-03-17                      4950                         9400
# 2021-03-18                      4730                         9340
# 2021-03-19                      4990                         9410
# ...                              ...                          ...
# 2024-03-11                      8330                        14910
# 2024-03-12                      8260                        14810
# 2024-03-13                      8240                        14750
# 2024-03-14                      8240                        14780
# 2024-03-15                      8190                        14795
#
#             Stok GKG Tingkat Penggilingan  Stok Beras Tingkat Penggilingan  \
# Komoditas
# 2021-03-15                             20                               10
# 2021-03-16                             70                               20
# 2021-03-17                             30                               10
# 2021-03-18                             40                               10
# 2021-03-19                             40                               10
# ...                                   ...                              ...
# 2024-03-11                            120                               80
# 2024-03-12                            120                               80
# 2024-03-13                            100                               60
# 2024-03-14                            150                               70
# 2024-03-15                            150                               80
#
#             Beras  Beras Kualitas Bawah  Beras Kualitas Medium  \
# Komoditas
# 2021-03-15  11200                  9800                  11150
# 2021-03-16  11200                  9800                  11150
# 2021-03-17  11200                  9800                  11150
# 2021-03-18  11200                  9775                  11175
# 2021-03-19  11200                  9800                  11150
# ...           ...                   ...                    ...
# 2024-03-11  15800                 14725                  15800
# 2024-03-12  15800                 14725                  15800
# 2024-03-13  15750                 14650                  15725
# 2024-03-14  15750                 14650                  15725
# 2024-03-15  15750                 14675                  15750
#
#             Beras Kualitas Super
# Komoditas
# 2021-03-15                 12650
# 2021-03-16                 12650
# 2021-03-17                 12650
# 2021-03-18                 12650
# 2021-03-19                 12650
# ...                          ...
# 2024-03-11                 16900
# 2024-03-12                 16900
# 2024-03-13                 16875
# 2024-03-14                 16875
# 2024-03-15                 16875
#
# [733 rows x 11 columns]

# %%
plt.plot(df3)
# df3[['GKP Tingkat Petani']].plot(style='.-', use_index=True)
# df3[['GKP Tingkat Petani']].loc['2020-01-01':'2024-03-01'].plot(style='.-')
plt.tight_layout()
plt.show()

# %%
#is the dataset df3 ready for time series analysis?
df3.info()
df3.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 733 entries, 2021-03-15 to 2024-03-15
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Luas Panen Padi                  733 non-null    Int64
#  1   GKP Tingkat Petani               733 non-null    Int64
#  2   GKP Tingkat Penggilingan         733 non-null    Int64
#  3   GKG Tingkat Penggilingan         733 non-null    Int64
#  4   Ratarata Beras Penggilingan      733 non-null    Int64
#  5   Stok GKG Tingkat Penggilingan    733 non-null    Int64
#  6   Stok Beras Tingkat Penggilingan  733 non-null    Int64
#  7   Beras                            733 non-null    Int64
#  8   Beras Kualitas Bawah             733 non-null    Int64
#  9   Beras Kualitas Medium            733 non-null    Int64
#  10  Beras Kualitas Super             733 non-null    Int64
# dtypes: Int64(11)
# memory usage: 76.6 KB
# Luas Panen Padi                     11
# GKP Tingkat Petani                 209
# GKP Tingkat Penggilingan           226
# GKG Tingkat Penggilingan           252
# Ratarata Beras Penggilingan        332
# Stok GKG Tingkat Penggilingan       37
# Stok Beras Tingkat Penggilingan     20
# Beras                               65
# Beras Kualitas Bawah                96
# Beras Kualitas Medium               83
# Beras Kualitas Super                83
# dtype: int64

# %%
df4 = pd.read_csv('./csv/distributor_pembelian.csv')
df4
# Out:
#        Komoditas        UMP BBM Solar quantity
# 0     01/01/2020  1,810,351     9,500  113,151
# 1     02/01/2020  1,810,351     9,500  113,151
# 2     03/01/2020  1,810,351     9,500  113,151
# 3     04/01/2020  1,810,351     9,500  113,151
# 4     05/01/2020  1,810,351     9,500  113,151
# ...          ...        ...       ...      ...
# 1531  11/03/2024  2,057,495     6,800  113,151
# 1532  12/03/2024  2,057,495     6,800  113,151
# 1533  13/03/2024  2,057,495     6,800  113,151
# 1534  14/03/2024  2,057,495     6,800  113,151
# 1535  15/03/2024  2,057,495     6,800  113,151
#
# [1536 rows x 4 columns]

# %%
#delete all commas in the data
df4['UMP'] = df4['UMP'].str.replace(',', '')
df4['BBM Solar'] = df4['BBM Solar'].str.replace(',', '')
df4['quantity'] = df4['quantity'].str.replace(',', '')
df4
# Out:
#        Komoditas      UMP BBM Solar quantity
# 0     01/01/2020  1810351      9500   113151
# 1     02/01/2020  1810351      9500   113151
# 2     03/01/2020  1810351      9500   113151
# 3     04/01/2020  1810351      9500   113151
# 4     05/01/2020  1810351      9500   113151
# ...          ...      ...       ...      ...
# 1531  11/03/2024  2057495      6800   113151
# 1532  12/03/2024  2057495      6800   113151
# 1533  13/03/2024  2057495      6800   113151
# 1534  14/03/2024  2057495      6800   113151
# 1535  15/03/2024  2057495      6800   113151
#
# [1536 rows x 4 columns]

# %%
#Mengubah tanggal menjadi index
con=df4['Komoditas']
df4['Komoditas'] = pd.to_datetime(df4['Komoditas'], format='%d/%m/%Y')
df4.set_index('Komoditas', inplace=True)
#check datatype of index
df4.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-09',
#                '2024-03-10', '2024-03-11', '2024-03-12', '2024-03-13',
#                '2024-03-14', '2024-03-15'],
#               dtype='datetime64[ns]', name='Komoditas', length=1536, freq=None)

# %%
df4 = df4.astype('Int64')
df4
# Out:
#                 UMP  BBM Solar  quantity
# Komoditas
# 2020-01-01  1810351       9500    113151
# 2020-01-02  1810351       9500    113151
# 2020-01-03  1810351       9500    113151
# 2020-01-04  1810351       9500    113151
# 2020-01-05  1810351       9500    113151
# ...             ...        ...       ...
# 2024-03-11  2057495       6800    113151
# 2024-03-12  2057495       6800    113151
# 2024-03-13  2057495       6800    113151
# 2024-03-14  2057495       6800    113151
# 2024-03-15  2057495       6800    113151
#
# [1536 rows x 3 columns]

# %%
df5 = pd.merge(df3, df4, on='Komoditas', how='left')
df5
# Out:
#             Luas Panen Padi  GKP Tingkat Petani  GKP Tingkat Penggilingan  \
# Komoditas
# 2021-03-15               10                4000                      4150
# 2021-03-16               10                3850                      4100
# 2021-03-17               10                4160                      4230
# 2021-03-18               10                4120                      4190
# 2021-03-19               10                4190                      4290
# ...                     ...                 ...                       ...
# 2024-03-11               10                6760                      7140
# 2024-03-12               10                6530                      6930
# 2024-03-13               10                6480                      6920
# 2024-03-14               10                6510                      7060
# 2024-03-15               10                6480                      6930
#
#             GKG Tingkat Penggilingan  Ratarata Beras Penggilingan  \
# Komoditas
# 2021-03-15                      5050                         9465
# 2021-03-16                      4740                         9360
# 2021-03-17                      4950                         9400
# 2021-03-18                      4730                         9340
# 2021-03-19                      4990                         9410
# ...                              ...                          ...
# 2024-03-11                      8330                        14910
# 2024-03-12                      8260                        14810
# 2024-03-13                      8240                        14750
# 2024-03-14                      8240                        14780
# 2024-03-15                      8190                        14795
#
#             Stok GKG Tingkat Penggilingan  Stok Beras Tingkat Penggilingan  \
# Komoditas
# 2021-03-15                             20                               10
# 2021-03-16                             70                               20
# 2021-03-17                             30                               10
# 2021-03-18                             40                               10
# 2021-03-19                             40                               10
# ...                                   ...                              ...
# 2024-03-11                            120                               80
# 2024-03-12                            120                               80
# 2024-03-13                            100                               60
# 2024-03-14                            150                               70
# 2024-03-15                            150                               80
#
#             Beras  Beras Kualitas Bawah  Beras Kualitas Medium  \
# Komoditas
# 2021-03-15  11200                  9800                  11150
# 2021-03-16  11200                  9800                  11150
# 2021-03-17  11200                  9800                  11150
# 2021-03-18  11200                  9775                  11175
# 2021-03-19  11200                  9800                  11150
# ...           ...                   ...                    ...
# 2024-03-11  15800                 14725                  15800
# 2024-03-12  15800                 14725                  15800
# 2024-03-13  15750                 14650                  15725
# 2024-03-14  15750                 14650                  15725
# 2024-03-15  15750                 14675                  15750
#
#             Beras Kualitas Super      UMP  BBM Solar  quantity
# Komoditas
# 2021-03-15                 12650  1810351       9600    113151
# 2021-03-16                 12650  1810351       9600    113151
# 2021-03-17                 12650  1810351       9600    113151
# 2021-03-18                 12650  1810351       9600    113151
# 2021-03-19                 12650  1810351       9600    113151
# ...                          ...      ...        ...       ...
# 2024-03-11                 16900  2057495       6800    113151
# 2024-03-12                 16900  2057495       6800    113151
# 2024-03-13                 16875  2057495       6800    113151
# 2024-03-14                 16875  2057495       6800    113151
# 2024-03-15                 16875  2057495       6800    113151
#
# [733 rows x 14 columns]

# %%
df5.nunique()
# Out:
# Luas Panen Padi                     11
# GKP Tingkat Petani                 209
# GKP Tingkat Penggilingan           226
# GKG Tingkat Penggilingan           252
# Ratarata Beras Penggilingan        332
# Stok GKG Tingkat Penggilingan       37
# Stok Beras Tingkat Penggilingan     20
# Beras                               65
# Beras Kualitas Bawah                96
# Beras Kualitas Medium               83
# Beras Kualitas Super                83
# UMP                                  4
# BBM Solar                            3
# quantity                             1
# dtype: int64

# %%
df5.corr()
# Out:
#                                  Luas Panen Padi  GKP Tingkat Petani  \
# Luas Panen Padi                         1.000000           -0.164905
# GKP Tingkat Petani                     -0.164905            1.000000
# GKP Tingkat Penggilingan               -0.193517            0.994734
# GKG Tingkat Penggilingan               -0.248987            0.985025
# Ratarata Beras Penggilingan            -0.184377            0.976199
# Stok GKG Tingkat Penggilingan          -0.121772            0.444965
# Stok Beras Tingkat Penggilingan        -0.202656            0.149439
# Beras                                  -0.183241            0.973301
# Beras Kualitas Bawah                   -0.184215            0.977386
# Beras Kualitas Medium                  -0.175557            0.972349
# Beras Kualitas Super                   -0.184913            0.961590
# UMP                                    -0.228584            0.870927
# BBM Solar                               0.295987           -0.523155
# quantity                                     NaN                 NaN
#
#                                  GKP Tingkat Penggilingan  \
# Luas Panen Padi                                 -0.193517
# GKP Tingkat Petani                               0.994734
# GKP Tingkat Penggilingan                         1.000000
# GKG Tingkat Penggilingan                         0.990028
# Ratarata Beras Penggilingan                      0.979224
# Stok GKG Tingkat Penggilingan                    0.442201
# Stok Beras Tingkat Penggilingan                  0.155998
# Beras                                            0.976628
# Beras Kualitas Bawah                             0.980254
# Beras Kualitas Medium                            0.975468
# Beras Kualitas Super                             0.965921
# UMP                                              0.873654
# BBM Solar                                       -0.505861
# quantity                                              NaN
#
#                                  GKG Tingkat Penggilingan  \
# Luas Panen Padi                                 -0.248987
# GKP Tingkat Petani                               0.985025
# GKP Tingkat Penggilingan                         0.990028
# GKG Tingkat Penggilingan                         1.000000
# Ratarata Beras Penggilingan                      0.982479
# Stok GKG Tingkat Penggilingan                    0.455465
# Stok Beras Tingkat Penggilingan                  0.182008
# Beras                                            0.978937
# Beras Kualitas Bawah                             0.981946
# Beras Kualitas Medium                            0.977152
# Beras Kualitas Super                             0.969887
# UMP                                              0.881153
# BBM Solar                                       -0.554359
# quantity                                              NaN
#
#                                  Ratarata Beras Penggilingan  \
# Luas Panen Padi                                    -0.184377
# GKP Tingkat Petani                                  0.976199
# GKP Tingkat Penggilingan                            0.979224
# GKG Tingkat Penggilingan                            0.982479
# Ratarata Beras Penggilingan                         1.000000
# Stok GKG Tingkat Penggilingan                       0.393384
# Stok Beras Tingkat Penggilingan                     0.123216
# Beras                                               0.991972
# Beras Kualitas Bawah                                0.994028
# Beras Kualitas Medium                               0.991625
# Beras Kualitas Super                                0.983144
# UMP                                                 0.906697
# BBM Solar                                          -0.552020
# quantity                                                 NaN
#
#                                  Stok GKG Tingkat Penggilingan  \
# Luas Panen Padi                                      -0.121772
# GKP Tingkat Petani                                    0.444965
# GKP Tingkat Penggilingan                              0.442201
# GKG Tingkat Penggilingan                              0.455465
# Ratarata Beras Penggilingan                           0.393384
# Stok GKG Tingkat Penggilingan                         1.000000
# Stok Beras Tingkat Penggilingan                       0.698509
# Beras                                                 0.427691
# Beras Kualitas Bawah                                  0.426235
# Beras Kualitas Medium                                 0.427292
# Beras Kualitas Super                                  0.429639
# UMP                                                   0.336361
# BBM Solar                                            -0.279596
# quantity                                                   NaN
#
#                                  Stok Beras Tingkat Penggilingan     Beras  \
# Luas Panen Padi                                        -0.202656 -0.183241
# GKP Tingkat Petani                                      0.149439  0.973301
# GKP Tingkat Penggilingan                                0.155998  0.976628
# GKG Tingkat Penggilingan                                0.182008  0.978937
# Ratarata Beras Penggilingan                             0.123216  0.991972
# Stok GKG Tingkat Penggilingan                           0.698509  0.427691
# Stok Beras Tingkat Penggilingan                         1.000000  0.172808
# Beras                                                   0.172808  1.000000
# Beras Kualitas Bawah                                    0.164300  0.998726
# Beras Kualitas Medium                                   0.172802  0.999387
# Beras Kualitas Super                                    0.186633  0.996205
# UMP                                                     0.056631  0.875405
# BBM Solar                                              -0.143843 -0.540143
# quantity                                                     NaN       NaN
#
#                                  Beras Kualitas Bawah  Beras Kualitas Medium  \
# Luas Panen Padi                             -0.184215              -0.175557
# GKP Tingkat Petani                           0.977386               0.972349
# GKP Tingkat Penggilingan                     0.980254               0.975468
# GKG Tingkat Penggilingan                     0.981946               0.977152
# Ratarata Beras Penggilingan                  0.994028               0.991625
# Stok GKG Tingkat Penggilingan                0.426235               0.427292
# Stok Beras Tingkat Penggilingan              0.164300               0.172802
# Beras                                        0.998726               0.999387
# Beras Kualitas Bawah                         1.000000               0.998661
# Beras Kualitas Medium                        0.998661               1.000000
# Beras Kualitas Super                         0.991112               0.994003
# UMP                                          0.885970               0.872179
# BBM Solar                                   -0.550686              -0.536578
# quantity                                          NaN                    NaN
#
#                                  Beras Kualitas Super       UMP  BBM Solar  \
# Luas Panen Padi                             -0.184913 -0.228584   0.295987
# GKP Tingkat Petani                           0.961590  0.870927  -0.523155
# GKP Tingkat Penggilingan                     0.965921  0.873654  -0.505861
# GKG Tingkat Penggilingan                     0.969887  0.881153  -0.554359
# Ratarata Beras Penggilingan                  0.983144  0.906697  -0.552020
# Stok GKG Tingkat Penggilingan                0.429639  0.336361  -0.279596
# Stok Beras Tingkat Penggilingan              0.186633  0.056631  -0.143843
# Beras                                        0.996205  0.875405  -0.540143
# Beras Kualitas Bawah                         0.991112  0.885970  -0.550686
# Beras Kualitas Medium                        0.994003  0.872179  -0.536578
# Beras Kualitas Super                         1.000000  0.856506  -0.522529
# UMP                                          0.856506  1.000000  -0.704116
# BBM Solar                                   -0.522529 -0.704116   1.000000
# quantity                                          NaN       NaN        NaN
#
#                                  quantity
# Luas Panen Padi                       NaN
# GKP Tingkat Petani                    NaN
# GKP Tingkat Penggilingan              NaN
# GKG Tingkat Penggilingan              NaN
# Ratarata Beras Penggilingan           NaN
# Stok GKG Tingkat Penggilingan         NaN
# Stok Beras Tingkat Penggilingan       NaN
# Beras                                 NaN
# Beras Kualitas Bawah                  NaN
# Beras Kualitas Medium                 NaN
# Beras Kualitas Super                  NaN
# UMP                                   NaN
# BBM Solar                             NaN
# quantity                              NaN

# %%
#and then plot the correlation
plt.matshow(df5.corr())
plt.show()

# %%
df5.corr()['Beras'].sort_values(ascending=False)
# Out:
# Beras                              1.000000
# Beras Kualitas Medium              0.999387
# Beras Kualitas Bawah               0.998726
# Beras Kualitas Super               0.996205
# Ratarata Beras Penggilingan        0.991972
# GKG Tingkat Penggilingan           0.978937
# GKP Tingkat Penggilingan           0.976628
# GKP Tingkat Petani                 0.973301
# UMP                                0.875405
# Stok GKG Tingkat Penggilingan      0.427691
# Stok Beras Tingkat Penggilingan    0.172808
# Luas Panen Padi                   -0.183241
# BBM Solar                         -0.540143
# quantity                                NaN
# Name: Beras, dtype: float64

# %%
#drop column Beras Kualitas Bawah I, Beras Kualitas Medium I, Beras Kualitas Super I
df5 = df5.drop(['Beras Kualitas Bawah', 'Beras Kualitas Medium', 'Beras Kualitas Super'], axis=1)

# %%
from catboost import CatBoostRegressor, Pool
import numpy as np

# Prepare the data
X = np.array(df5.index).reshape(-1, 1)
y = df5['Beras'].values

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Convert y_train and y_test to numpy arrays
y_train = y_train.to_numpy(dtype=np.float32)
y_test = y_test.to_numpy(dtype=np.float32)

# Create a Pool from the training data
train_pool = Pool(X_train, y_train)

# Initialize CatBoostRegressor
model = CatBoostRegressor(iterations=1000,
                          learning_rate=0.1,
                          depth=10,
                          loss_function='RMSE',
                          verbose=200)

# Fit model
model.fit(train_pool)

# Get predictions
preds = model.predict(X_test)
# Out:
# 0:	learn: 461.2575951	total: 2.36ms	remaining: 2.35s
# 200:	learn: 31.4592977	total: 339ms	remaining: 1.35s
# 400:	learn: 30.4918612	total: 672ms	remaining: 1s
# 600:	learn: 30.3798489	total: 996ms	remaining: 662ms
# 800:	learn: 30.3556131	total: 1.32s	remaining: 328ms
# 999:	learn: 30.3482435	total: 1.64s	remaining: 0us

# %%
# Assuming you have a model called 'model' and test data 'X_test' and 'y_test'
y_true = y_test
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_true, y_pred)

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_true, y_pred)

from math import sqrt
rmse = sqrt(mse)

from sklearn.metrics import r2_score
r2 = r2_score(y_true, y_pred)

#evaluate the model
print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
print(f'R2 Score: {r2}')
# Out:
# Mean Absolute Error: 1641.2526556716255
# Mean Squared Error: 3303620.733726674
# Root Mean Squared Error: 1817.586513409107
# R2 Score: -4.416566853256637
